# %%
import os
import sys
import numpy as np
import torch
import ast
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
sys.path.append("../authorship_attribution/")
sys.path.append("../obfuscated_ast_similarity//")

# %%
import model as ast_model
import train as ast_train
import utilities as ast_utilities
import obfuscation
import json
import obfuscated_trainer

# %%
original_path = "../authorship_attribution/experiments/GCJ-108/plain/"

# %%
# complete_model = ast_utilities.load_plain_model(complete_model, )
# model_params = json.loads(open(os.path.join(path, "components", "ast_encoder_params.json")).read())
model_params = json.loads(open(os.path.join(original_path, "best_state", "components", "ast_encoder_params.json")).read())

# %%
ast_encoder = ast_model.ASTEncoder(model_params)
ast_encoder.load(os.path.join(original_path, "best_state", "components"))

# %%
batcher = obfuscated_trainer.Batcher({}, 0.8)
batcher.load_from_attribution_batcher(original_path)
# batcher.load_from_attribution_batcher("../authorship_attribution/experiments/GCJ-108/regularized-sep-coef-names/")
# batcher.load(original_path)

# %%
# batcher.train_data

# %%
# data = ast_utilities.read_all_gcj()

# %%
# data = ast_utilities.filter_by_count(data, 15, 1000)
# batcher = obfuscated_trainer.Batcher(data, 0.8)

# %%
# obfuscation_params = {
#     'add_kvargs':0.5,
#     'add_args':0.5,
#     'args_max_add':5,
#     'add_call_args':0.5,
#     'call_args':3,
#     'call_kwargs':3,
#     'if_swap':0.5,
#     'modify_body':0.5,
#     'n_modification_depth':3,
#     'max_trash_to_body':3,
#     'swap_in_body':0.5
# }

# obfuscation_params = {
#     'add_kvargs':0.8,
#     'add_args':0.8,
#     'args_max_add':8,
#     'add_call_args':0.8,
#     'call_args':5,
#     'call_kwargs':5,
#     'if_swap':0.7,
#     'modify_body':0.7,
#     'n_modification_depth':5,
#     'max_trash_to_body':5,
#     'swap_in_body':0.6
# }

# obfuscation_params = {
#     'add_kvargs':0.3,
#     'add_args':0.3,
#     'args_max_add':3,
#     'add_call_args':0.5,
#     'call_args':3,
#     'call_kwargs':3,
#     'if_swap':0.4,
#     'modify_body':0.4,
#     'n_modification_depth':2,
#     'max_trash_to_body':5,
#     'swap_in_body':0.5
# }

obfuscation_params = {
    'add_kvargs':0.2,
    'add_args':0.2,
    'args_max_add':3,
    'add_call_args':0.5,
    'call_args':3,
    'call_kwargs':3,
    'if_swap':0.3,
    'modify_body':0.4,
    'n_modification_depth':1,
    'max_trash_to_body':1,
    'swap_in_body':0.5
}


# obfuscation_params = {
#     'add_kvargs':0.0,
#     'add_args':0.0,
#     'args_max_add':0,
#     'add_call_args':0.0,
#     'call_args':0,
#     'call_kwargs':0,
#     'if_swap':0.0,
#     'modify_body':0.0,
#     'n_modification_depth':0,
#     'max_trash_to_body':0,
#     'swap_in_body':0.0
# }

# %%
# print()

# %%
long_names = obfuscated_trainer.order_names_by_count(batcher)

# %%
validation_before = obfuscated_trainer.validate(ast_encoder, batcher, long_names, obfuscation_params, max_for_user=100, n_obfuscated=2)

# %%
# trainer_params = dict(
#     n_epochs = 200,
#     n_obfuscated = 25,
#     validate_every = 5,
#     n_problems_validation = 50,
#     validate_n_problems = 50,
#     train_n_problems = 50,
#     regularizer_coef = 0.001,
#     n_adversarial = 100,
#     adversarial_coef = 1
# )


trainer_params = dict(
    n_epochs = 200,
    n_obfuscated = 25,
    validate_every = 5,
    n_problems_validation = 50,
    validate_n_problems = 10,
    train_n_problems = 10,
    regularizer_coef = 0.000,
    n_adversarial = 10,
    adversarial_coef = 1
)

# %%
track_metric = {
    "metric_name":"loss",
    "function":ast_train.validate_max
}

# %%
# batcher = obfuscated_trainer.Batcher(data, 0.8)
# !ls
# Out:
# Anytask-on-Anytask.ipynb	  GCJ-108-only-positive.ipynb
# Anytask-on-GCJ-108.ipynb	  GCJ-108-params-1.ipynb
# experiments			  GCJ-108-params-2.ipynb
# GCJ-108-from_scratch.ipynb	  GCJ-108-Subseq.ipynb
# GCJ-108.ipynb			  mix_code.ipynb
# GCJ-108-mixing-code.ipynb	  most_common_names_all_datasets.pkl
# GCJ-108-more-negative.ipynb	  obfuscated_trainer.py
# GCJ-108-more-negative-more.ipynb  obfuscation.py
# GCJ-108-names.ipynb		  __pycache__
# GCJ-108-only-negative.ipynb	  training_obfuscated_ast_discriminator.ipynb

# %%
path = "./experiments/gcj_108_108/pure/params/params2"
if os.path.exists(path):
    raise ValueError()

# %%
trainer = obfuscated_trainer.Trainer(ast_encoder, torch.optim.Adam(ast_encoder.parameters()), path=path, track_metric=track_metric)

# %%
# trainer.load(os.path.join(path, "last_state"))

# %%
trainer.train(batcher, trainer_params, obfuscation_params)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-17243bec2aae> in <module>()
# ----> 1 trainer.train(batcher, trainer_params, obfuscation_params)
#
# ~/projects/obfuscated_ast_similarity/obfuscated_trainer.py in train(self, batcher, params, obfuscation_params)
#     702 #                 code = list(sorted(current_data.keys()))[np.random.choice(cur_len)]
#     703 #                 code = batcher.get_train_code()
# --> 704                 cur_loss, cur_reprs, _ = loss_for_problem(self.ast_encoder, code, params['n_obfuscated'], obfuscation_params)
#     705 #                 print("OK")
#     706
#
# ~/projects/obfuscated_ast_similarity/obfuscated_trainer.py in loss_for_problem(ast_encoder, code, n_tests, obfuscation_params)
#     207 #     sns.heatmap(get_multi_similarity_matrix(ast_encoder, code, n_tests, obfuscation_params)[0])
#     208 #     plt.show()
# --> 209     obfuscated_repr, obfuscated = get_n_obfuscated_representations(ast_encoder, code, n_tests, obfuscation_params)
#     210     obfuscated_repr = torch.cat(obfuscated_repr, dim=0)
#     211
#
# ~/projects/obfuscated_ast_similarity/obfuscated_trainer.py in get_n_obfuscated_representations(ast_encoder, code, n_tests, obfuscation_params)
#     263 #             print(obfuscated)
#     264             obfuscated_list.append(obfuscated)
# --> 265             obfuscated_repr = ast_encoder(ast.parse(obfuscated)).view(1, -1)
#     266             data_points.append(obfuscated_repr)
#     267 #     print("OK")
#
# ~/torch/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/projects/authorship_attribution/model.py in forward(self, node)
#     192
#     193     def forward(self, node):
# --> 194         return self.visitor.visit(node)
#     195
#     196
#
# ~/projects/authorship_attribution/model.py in visit(self, node)
#      50
#      51     def visit(self, node):
# ---> 52         return self.embed_node(node)
#      53
#      54     def node_to_index(self, node):
#
# ~/projects/authorship_attribution/model.py in embed_node(self, node)
#      69         if len(list(ast.iter_child_nodes(node))):
#      70             embeddings = [node_embedding]
# ---> 71             embeddings += self.embed_subtree(node)
#      72             # result = self.embedding_network(torch.cat((node_embedding, subtree_embedding), -1))
#      73             # c_0 = torch.zeros(1, self.embedding_dim)
#
# ~/projects/authorship_attribution/model.py in embed_subtree(self, node)
#     103         for child in ast.iter_child_nodes(node):
#     104             # print(child)
# --> 105             child_embedding = self.embed_node(child).view(1, -1)
#     106             children_embeddings.append(child_embedding)
#     107             # (c_0, h_0) = self.subtree_network(child_embedding, (c_0, h_0))
#
# ~/projects/authorship_attribution/model.py in embed_node(self, node)
#      74             # h_0 = torch.zeros(1, self.embedding_dim)
#      75
# ---> 76             embeddings = torch.cat(embeddings, 0).unsqueeze(0)
#      77
#      78
#
# KeyboardInterrupt:

# %%
validation_result = obfuscated_trainer.validate(ast_encoder, batcher, long_names, obfuscation_params, max_for_user=100, n_obfuscated=5)
