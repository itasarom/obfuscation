# %%
import os
import sys
import numpy as np
import torch
import ast
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
sys.path.append("../authorship_attribution/")
sys.path.append("../obfuscated_ast_similarity//")

# %%
import model as ast_model
import train as ast_train
import utilities as ast_utilities
import obfuscation
import json
import obfuscated_trainer

# %%
original_path = "../authorship_attribution/experiments/GCJ-108/plain/"

# %%
# complete_model = ast_utilities.load_plain_model(complete_model, )
# model_params = json.loads(open(os.path.join(path, "components", "ast_encoder_params.json")).read())
model_params = json.loads(open(os.path.join(original_path, "best_state", "components", "ast_encoder_params.json")).read())

# %%
ast_encoder = ast_model.ASTEncoder(model_params)
ast_encoder.load(os.path.join(original_path, "best_state", "components"))

# %%
batcher = obfuscated_trainer.Batcher({}, 0.8)
batcher.load_from_attribution_batcher(original_path)
# batcher.load_from_attribution_batcher("../authorship_attribution/experiments/GCJ-108/regularized-sep-coef-names/")
# batcher.load(original_path)

# %%
# batcher.train_data

# %%
# data = ast_utilities.read_all_gcj()

# %%
# data = ast_utilities.filter_by_count(data, 15, 1000)
# batcher = obfuscated_trainer.Batcher(data, 0.8)

# %%
obfuscation_params = {
    "max_patches_to_body":5,
    "modify_add_patches":0.5,
    "max_frac_to_insert":0.3,
#     'max_n_insertions':5,
    "add_functions":False
}

# %%
long_names = obfuscated_trainer.order_names_by_count(batcher)

# %%
# obfuscated_trainer.validate(ast_encoder, batcher, long_names, obfuscation_params, n_first_for_person=10, n_obfuscated=2)

# %%
# trainer_params = dict(
#     n_epochs = 200,
#     n_obfuscated = 25,
#     validate_every = 5,
#     n_problems_validation = 50,
#     validate_n_problems = 50,
#     train_n_problems = 50,
#     regularizer_coef = 0.001,
#     n_adversarial = 100,
#     adversarial_coef = 1
# )


trainer_params = dict(
    n_epochs = 200,
    n_obfuscated = 25,
    validate_every = 5,
    n_problems_validation = 50,
    validate_n_problems = 10,
    train_n_problems = 10,
    regularizer_coef = 0.000,
    n_adversarial = 10,
    adversarial_coef = 1
)

# %%
track_metric = {
    "metric_name":"loss",
    "function":ast_train.validate_max
}

# %%
path = "./experiments/gcj_108_108/pure/no_names_mixing"
if os.path.exists(path):
    raise ValueError()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d4e4ded1537e> in <module>()
#       1 path = "./experiments/gcj_108_108/pure/no_names_mixing"
#       2 if os.path.exists(path):
# ----> 3     raise ValueError()
#
# ValueError:

# %%
trainer = obfuscated_trainer.MixingTrainer(ast_encoder, torch.optim.Adam(ast_encoder.parameters()), path=path, track_metric=track_metric)

# %%
trainer.train(batcher, trainer_params, obfuscation_params)

# %%
obfuscated_trainer.validate(ast_encoder, batcher, long_names, obfuscation_params, n_first_for_person=10, n_obfuscated=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-7bbc43d09908> in <module>()
# ----> 1 obfuscated_trainer.validate(ast_encoder, batcher, long_names, obfuscation_params, n_first_for_person=10, n_obfuscated=2)
#
# ~/projects/obfuscated_ast_similarity/obfuscated_trainer.py in validate(ast_encoder, batcher, long_names, obfuscation_params, n_first_for_person, n_obfuscated)
#     347
#     348 def validate(ast_encoder, batcher, long_names, obfuscation_params, n_first_for_person, n_obfuscated):
# --> 349     sim, indices, data_indices = create_similarity_matrix(ast_encoder, long_names, batcher.train_data, obfuscation_params, n_first_for_person=n_first_for_person, n_obfuscated=n_obfuscated)
#     350     print("Train:")
#     351     print_validation_result(sim, indices, data_indices)
#
# ~/projects/obfuscated_ast_similarity/obfuscated_trainer.py in create_similarity_matrix(ast_encoder, names, data, obfuscation_params, n_first_for_person, n_obfuscated)
#     319         data_indices.append(list(range(start, end, 1)))
#     320
# --> 321     sim, indices = get_multi_similarity_matrix(ast_encoder, data_points, n_obfuscated, obfuscation_params)
#     322 #     plt.figure(figsize=(15, 15))
#     323 #     sns.heatmap(sim, vmin=-1.0, vmax=1.0)
#
# ~/projects/obfuscated_ast_similarity/obfuscated_trainer.py in get_multi_similarity_matrix(ast_encoder, code_list, n_tests, obfuscation_params)
#     212         indices_by_user.append(list(range(len(data_points), len(data_points) + n_tests + 1, 1)))
#     213         data_points.append(ast_encoder(ast.parse(code)).view(1, -1))
# --> 214         data_points += get_n_obfuscated_representations(ast_encoder, code, n_tests, obfuscation_params)[0]
#     215
#     216
#
# ~/projects/obfuscated_ast_similarity/obfuscated_trainer.py in get_n_obfuscated_representations(ast_encoder, code, n_tests, obfuscation_params)
#     188     for i in range(n_tests):
#     189 #             print(code)
# --> 190             obfuscated = obfuscation.obfuscate(code, obfuscation_params)
#     191 #             print(obfuscated)
#     192             obfuscated_list.append(obfuscated)
#
# ~/projects/obfuscated_ast_similarity/obfuscation.py in obfuscate(code, params)
#     268
#     269     result = parsed
# --> 270     for i in range(params['n_modification_depth']):
#     271         result = modify(result, params)
#     272
#
# KeyError: 'n_modification_depth'
