# %%
import os
import sys
import numpy as np
import torch
import ast
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
sys.path.append("../authorship_attribution/")
sys.path.append("../obfuscated_ast_similarity//")

# %%
import model as ast_model
import train as ast_train
import utilities as ast_utilities
import obfuscation
import json
import obfuscated_trainer

# %%
original_path = "../authorship_attribution/experiments/GCJ-108/plain/"

# %%
# complete_model = ast_utilities.load_plain_model(complete_model, )
# model_params = json.loads(open(os.path.join(path, "components", "ast_encoder_params.json")).read())
model_params = json.loads(open(os.path.join(original_path, "best_state", "components", "ast_encoder_params.json")).read())

# %%
ast_encoder = ast_model.ASTEncoder(model_params)
# ast_encoder.load(os.path.join(original_path, "best_state", "components"))

# %%
batcher = obfuscated_trainer.Batcher({}, 0.8)
batcher.load_from_attribution_batcher(original_path)
# batcher.load_from_attribution_batcher("../authorship_attribution/experiments/GCJ-108/regularized-sep-coef-names/")
# batcher.load(original_path)

# %%
# batcher.train_data

# %%
# data = ast_utilities.read_all_gcj()

# %%
# data = ast_utilities.filter_by_count(data, 15, 1000)
# batcher = obfuscated_trainer.Batcher(data, 0.8)

# %%
# obfuscation_params = {
#     'add_kvargs':0.5,
#     'add_args':0.5,
#     'args_max_add':5,
#     'add_call_args':0.5,
#     'call_args':3,
#     'call_kwargs':3,
#     'if_swap':0.5,
#     'modify_body':0.5,
#     'n_modification_depth':3,
#     'max_trash_to_body':3,
#     'swap_in_body':0.5
# }

# obfuscation_params = {
#     'add_kvargs':0.8,
#     'add_args':0.8,
#     'args_max_add':8,
#     'add_call_args':0.8,
#     'call_args':5,
#     'call_kwargs':5,
#     'if_swap':0.7,
#     'modify_body':0.7,
#     'n_modification_depth':5,
#     'max_trash_to_body':5,
#     'swap_in_body':0.6
# }

# obfuscation_params = {
#     'add_kvargs':0.3,
#     'add_args':0.3,
#     'args_max_add':3,
#     'add_call_args':0.5,
#     'call_args':3,
#     'call_kwargs':3,
#     'if_swap':0.4,
#     'modify_body':0.4,
#     'n_modification_depth':2,
#     'max_trash_to_body':5,
#     'swap_in_body':0.5
# }

obfuscation_params = {
    'add_kvargs':0.3,
    'add_args':0.3,
    'args_max_add':10,
    'add_call_args':0.5,
    'call_args':10,
    'call_kwargs':10,
    'if_swap':0.5,
    'modify_body':0.4,
    'n_modification_depth':3,
    'max_trash_to_body':5,
    'swap_in_body':0.5
}


# obfuscation_params = {
#     'add_kvargs':0.0,
#     'add_args':0.0,
#     'args_max_add':0,
#     'add_call_args':0.0,
#     'call_args':0,
#     'call_kwargs':0,
#     'if_swap':0.0,
#     'modify_body':0.0,
#     'n_modification_depth':0,
#     'max_trash_to_body':0,
#     'swap_in_body':0.0
# }

# %%
long_names = obfuscated_trainer.order_names_by_count(batcher)

# %%
# "0" < "_"

# %%
validation_before = obfuscated_trainer.validate(ast_encoder, batcher, long_names, obfuscation_params, max_for_user=100, n_obfuscated=5)
# Out:
# Train:
# same_user_original 0.017806641991159687
# same_problem_user 0.00030103835621914413
# same_user 0.013533511653073193

# %%
validation_result = _

# %%
import seaborn as sns
def print_metrics(test_result):
#     print("Test:")
    counters = obfuscated_trainer.calculate_metric_counters(test_result["sim"], test_result["indices"], test_result["back_indices"])
    metrics = obfuscated_trainer.calculate_metrics(counters)
    for metric_name, metric in metrics.items():
        print(metric_name, np.mean(list(metric.values())))
        
    plt.figure(figsize=(15, 15))
    plt.title("test similarity")
    sns.heatmap(test_result["sim"], vmin=-1.0, vmax=1.0)

# %%
print_metrics(validation_result[0])
# Out:
# same_user_original 0.017806641991159687
# same_problem_user 0.00030103835621914413
# same_user 0.013533511653073193

# %%
print_metrics(validation_result[1])

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3f786850e387> in <module>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
validation_result[0]["indices"]["__fictional__"]
# Out:
# defaultdict(dict,
#             {0: {0: 661, 1: 662, 'original': 660},
#              1: {0: 664, 1: 665, 'original': 663},
#              2: {0: 667, 1: 668, 'original': 666},
#              3: {0: 670, 1: 671, 'original': 669},
#              4: {0: 673, 1: 674, 'original': 672}})

# %%
# trainer_params = dict(
#     n_epochs = 200,
#     n_obfuscated = 25,
#     validate_every = 5,
#     n_problems_validation = 50,
#     validate_n_problems = 50,
#     train_n_problems = 50,
#     regularizer_coef = 0.001,
#     n_adversarial = 100,
#     adversarial_coef = 1
# )


trainer_params = dict(
    n_epochs = 200,
    n_obfuscated = 25,
    validate_every = 5,
    n_problems_validation = 50,
    validate_n_problems = 10,
    train_n_problems = 10,
    regularizer_coef = 0.000,
    n_adversarial = 10,
    adversarial_coef = 1
)

# %%
track_metric = {
    "metric_name":"loss",
    "function":ast_train.validate_max
}

# %%
# batcher = obfuscated_trainer.Batcher(data, 0.8)
# !ls
# Out:
# Anytask-on-Anytask.ipynb	  GCJ-108-only-negative.ipynb
# Anytask-on-GCJ-108.ipynb	  GCJ-108-Subseq.ipynb
# experiments			  mix_code.ipynb
# GCJ-108-from_scratch.ipynb	  most_common_names_all_datasets.pkl
# GCJ-108.ipynb			  obfuscated_trainer.py
# GCJ-108-mixing-code.ipynb	  obfuscation.py
# GCJ-108-more-negative.ipynb	  __pycache__
# GCJ-108-more-negative-more.ipynb  training_obfuscated_ast_discriminator.ipynb
# GCJ-108-names.ipynb

# %%
path = "./experiments/gcj_108_108/pure/from_scratch"
if os.path.exists(path):
    raise ValueError()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-1afe99d3ff05> in <module>()
#       1 path = "./experiments/gcj_108_108/pure/from_scratch"
#       2 if os.path.exists(path):
# ----> 3     raise ValueError()
#
# ValueError:

# %%
trainer = obfuscated_trainer.Trainer(ast_encoder, torch.optim.Adam(ast_encoder.parameters()), path=path, track_metric=track_metric)

# %%
trainer.load(os.path.join(path, "last_state"))

# %%
trainer.train(batcher, trainer_params, obfuscation_params)

# %%
validation_result = obfuscated_trainer.validate(ast_encoder, batcher, long_names, obfuscation_params, max_for_user=5, n_obfuscated=5)
# Out:
# Train:
# same_user 0.10152905198776757
# same_user_original 0.13027522935779817
# same_problem_user 0.0400611620795107
# Test:
# same_user 0.09069826707441386
# same_user_original 0.13379204892966362
# same_problem_user 0.05568297655453618

# %%
# validation_result_new

# %%
# validation_result_2 = obfuscated_trainer.validate(ast_encoder, batcher, long_names, obfuscation_params, max_for_user=5, n_obfuscated=5)

# %%
# validation_result__ = obfuscated_trainer.validate(ast_encoder, batcher, long_names[:20], obfuscation_params, max_for_user=100, n_obfuscated=5)

# %%
# validation_result = obfuscated_trainer.validate(ast_encoder, batcher, long_names, obfuscation_params, max_for_user=100, n_obfuscated=5)

# %%
# list(map(lambda x: len(x), validation_result[1]['indices'].values()))

# %%
def print_metrics(test_result):
#     print("Test:")
    counters = obfuscated_trainer.calculate_metric_counters(test_result["sim"], test_result["indices"], test_result["back_indices"])
    metrics = obfuscated_trainer.calculate_metrics(counters)
    for metric_name, metric in metrics.items():
        print(metric_name, np.mean(list(metric.values())))

#     plt.figure(figsize=(15, 15))
#     plt.title("test similarity")
#     sns.heatmap(test_result["sim"], vmin=-1.0, vmax=1.0)

# %%
print_metrics(validation_result[1])
# Out:
# same_user 0.31376185237571375
# same_user_original 0.4932098765432098
# same_problem_user 0.24164734557992984

# %%
validation_result[1]['back_indices']
# Out:
# [('pawko0', 0, 'original'),
#  ('pawko0', 0, 0),
#  ('pawko0', 0, 1),
#  ('pawko0', 0, 2),
#  ('pawko0', 0, 3),
#  ('pawko0', 0, 4),
#  ('pawko0', 1, 'original'),
#  ('pawko0', 1, 0),
#  ('pawko0', 1, 1),
#  ('pawko0', 1, 2),
#  ('pawko0', 1, 3),
#  ('pawko0', 1, 4),
#  ('pawko0', 2, 'original'),
#  ('pawko0', 2, 0),
#  ('pawko0', 2, 1),
#  ('pawko0', 2, 2),
#  ('pawko0', 2, 3),
#  ('pawko0', 2, 4),
#  ('pawko0', 3, 'original'),
#  ('pawko0', 3, 0),
#  ('pawko0', 3, 1),
#  ('pawko0', 3, 2),
#  ('pawko0', 3, 3),
#  ('pawko0', 3, 4),
#  ('pawko0', 4, 'original'),
#  ('pawko0', 4, 0),
#  ('pawko0', 4, 1),
#  ('pawko0', 4, 2),
#  ('pawko0', 4, 3),
#  ('pawko0', 4, 4),
#  ('pawko0', 5, 'original'),
#  ('pawko0', 5, 0),
#  ('pawko0', 5, 1),
#  ('pawko0', 5, 2),
#  ('pawko0', 5, 3),
#  ('pawko0', 5, 4),
#  ('pawko0', 6, 'original'),
#  ('pawko0', 6, 0),
#  ('pawko0', 6, 1),
#  ('pawko0', 6, 2),
#  ('pawko0', 6, 3),
#  ('pawko0', 6, 4),
#  ('pawko0', 7, 'original'),
#  ('pawko0', 7, 0),
#  ('pawko0', 7, 1),
#  ('pawko0', 7, 2),
#  ('pawko0', 7, 3),
#  ('pawko0', 7, 4),
#  ('Jethol0', 0, 'original'),
#  ('Jethol0', 0, 0),
#  ('Jethol0', 0, 1),
#  ('Jethol0', 0, 2),
#  ('Jethol0', 0, 3),
#  ('Jethol0', 0, 4),
#  ('Jethol0', 1, 'original'),
#  ('Jethol0', 1, 0),
#  ('Jethol0', 1, 1),
#  ('Jethol0', 1, 2),
#  ('Jethol0', 1, 3),
#  ('Jethol0', 1, 4),
#  ('Jethol0', 2, 'original'),
#  ('Jethol0', 2, 0),
#  ('Jethol0', 2, 1),
#  ('Jethol0', 2, 2),
#  ('Jethol0', 2, 3),
#  ('Jethol0', 2, 4),
#  ('pablo.t890', 0, 'original'),
#  ('pablo.t890', 0, 0),
#  ('pablo.t890', 0, 1),
#  ('pablo.t890', 0, 2),
#  ('pablo.t890', 0, 3),
#  ('pablo.t890', 0, 4),
#  ('pablo.t890', 1, 'original'),
#  ('pablo.t890', 1, 0),
#  ('pablo.t890', 1, 1),
#  ('pablo.t890', 1, 2),
#  ('pablo.t890', 1, 3),
#  ('pablo.t890', 1, 4),
#  ('pablo.t890', 2, 'original'),
#  ('pablo.t890', 2, 0),
#  ('pablo.t890', 2, 1),
#  ('pablo.t890', 2, 2),
#  ('pablo.t890', 2, 3),
#  ('pablo.t890', 2, 4),
#  ('pablo.t890', 3, 'original'),
#  ('pablo.t890', 3, 0),
#  ('pablo.t890', 3, 1),
#  ('pablo.t890', 3, 2),
#  ('pablo.t890', 3, 3),
#  ('pablo.t890', 3, 4),
#  ('pablo.t890', 4, 'original'),
#  ('pablo.t890', 4, 0),
#  ('pablo.t890', 4, 1),
#  ('pablo.t890', 4, 2),
#  ('pablo.t890', 4, 3),
#  ('pablo.t890', 4, 4),
#  ('d.operator0', 0, 'original'),
#  ('d.operator0', 0, 0),
#  ('d.operator0', 0, 1),
#  ('d.operator0', 0, 2),
#  ('d.operator0', 0, 3),
#  ('d.operator0', 0, 4),
#  ('d.operator0', 1, 'original'),
#  ('d.operator0', 1, 0),
#  ('d.operator0', 1, 1),
#  ('d.operator0', 1, 2),
#  ('d.operator0', 1, 3),
#  ('d.operator0', 1, 4),
#  ('d.operator0', 2, 'original'),
#  ('d.operator0', 2, 0),
#  ('d.operator0', 2, 1),
#  ('d.operator0', 2, 2),
#  ('d.operator0', 2, 3),
#  ('d.operator0', 2, 4),
#  ('d.operator0', 3, 'original'),
#  ('d.operator0', 3, 0),
#  ('d.operator0', 3, 1),
#  ('d.operator0', 3, 2),
#  ('d.operator0', 3, 3),
#  ('d.operator0', 3, 4),
#  ('d.operator0', 4, 'original'),
#  ('d.operator0', 4, 0),
#  ('d.operator0', 4, 1),
#  ('d.operator0', 4, 2),
#  ('d.operator0', 4, 3),
#  ('d.operator0', 4, 4),
#  ('d.operator0', 5, 'original'),
#  ('d.operator0', 5, 0),
#  ('d.operator0', 5, 1),
#  ('d.operator0', 5, 2),
#  ('d.operator0', 5, 3),
#  ('d.operator0', 5, 4),
#  ('d.operator0', 6, 'original'),
#  ('d.operator0', 6, 0),
#  ('d.operator0', 6, 1),
#  ('d.operator0', 6, 2),
#  ('d.operator0', 6, 3),
#  ('d.operator0', 6, 4),
#  ('ana.valeije0', 0, 'original'),
#  ('ana.valeije0', 0, 0),
#  ('ana.valeije0', 0, 1),
#  ('ana.valeije0', 0, 2),
#  ('ana.valeije0', 0, 3),
#  ('ana.valeije0', 0, 4),
#  ('ana.valeije0', 1, 'original'),
#  ('ana.valeije0', 1, 0),
#  ('ana.valeije0', 1, 1),
#  ('ana.valeije0', 1, 2),
#  ('ana.valeije0', 1, 3),
#  ('ana.valeije0', 1, 4),
#  ('ana.valeije0', 2, 'original'),
#  ('ana.valeije0', 2, 0),
#  ('ana.valeije0', 2, 1),
#  ('ana.valeije0', 2, 2),
#  ('ana.valeije0', 2, 3),
#  ('ana.valeije0', 2, 4),
#  ('ana.valeije0', 3, 'original'),
#  ('ana.valeije0', 3, 0),
#  ('ana.valeije0', 3, 1),
#  ('ana.valeije0', 3, 2),
#  ('ana.valeije0', 3, 3),
#  ('ana.valeije0', 3, 4),
#  ('dareonion0', 0, 'original'),
#  ('dareonion0', 0, 0),
#  ('dareonion0', 0, 1),
#  ('dareonion0', 0, 2),
#  ('dareonion0', 0, 3),
#  ('dareonion0', 0, 4),
#  ('dareonion0', 1, 'original'),
#  ('dareonion0', 1, 0),
#  ('dareonion0', 1, 1),
#  ('dareonion0', 1, 2),
#  ('dareonion0', 1, 3),
#  ('dareonion0', 1, 4),
#  ('dareonion0', 2, 'original'),
#  ('dareonion0', 2, 0),
#  ('dareonion0', 2, 1),
#  ('dareonion0', 2, 2),
#  ('dareonion0', 2, 3),
#  ('dareonion0', 2, 4),
#  ('dareonion0', 3, 'original'),
#  ('dareonion0', 3, 0),
#  ('dareonion0', 3, 1),
#  ('dareonion0', 3, 2),
#  ('dareonion0', 3, 3),
#  ('dareonion0', 3, 4),
#  ('dareonion0', 4, 'original'),
#  ('dareonion0', 4, 0),
#  ('dareonion0', 4, 1),
#  ('dareonion0', 4, 2),
#  ('dareonion0', 4, 3),
#  ('dareonion0', 4, 4),
#  ('farin0', 0, 'original'),
#  ('farin0', 0, 0),
#  ('farin0', 0, 1),
#  ('farin0', 0, 2),
#  ('farin0', 0, 3),
#  ('farin0', 0, 4),
#  ('farin0', 1, 'original'),
#  ('farin0', 1, 0),
#  ('farin0', 1, 1),
#  ('farin0', 1, 2),
#  ('farin0', 1, 3),
#  ('farin0', 1, 4),
#  ('farin0', 2, 'original'),
#  ('farin0', 2, 0),
#  ('farin0', 2, 1),
#  ('farin0', 2, 2),
#  ('farin0', 2, 3),
#  ('farin0', 2, 4),
#  ('farin0', 3, 'original'),
#  ('farin0', 3, 0),
#  ('farin0', 3, 1),
#  ('farin0', 3, 2),
#  ('farin0', 3, 3),
#  ('farin0', 3, 4),
#  ('wheleph0', 0, 'original'),
#  ('wheleph0', 0, 0),
#  ('wheleph0', 0, 1),
#  ('wheleph0', 0, 2),
#  ('wheleph0', 0, 3),
#  ('wheleph0', 0, 4),
#  ('wheleph0', 1, 'original'),
#  ('wheleph0', 1, 0),
#  ('wheleph0', 1, 1),
#  ('wheleph0', 1, 2),
#  ('wheleph0', 1, 3),
#  ('wheleph0', 1, 4),
#  ('wheleph0', 2, 'original'),
#  ('wheleph0', 2, 0),
#  ('wheleph0', 2, 1),
#  ('wheleph0', 2, 2),
#  ('wheleph0', 2, 3),
#  ('wheleph0', 2, 4),
#  ('wheleph0', 3, 'original'),
#  ('wheleph0', 3, 0),
#  ('wheleph0', 3, 1),
#  ('wheleph0', 3, 2),
#  ('wheleph0', 3, 3),
#  ('wheleph0', 3, 4),
#  ('pumaking940', 0, 'original'),
#  ('pumaking940', 0, 0),
#  ('pumaking940', 0, 1),
#  ('pumaking940', 0, 2),
#  ('pumaking940', 0, 3),
#  ('pumaking940', 0, 4),
#  ('pumaking940', 1, 'original'),
#  ('pumaking940', 1, 0),
#  ('pumaking940', 1, 1),
#  ('pumaking940', 1, 2),
#  ('pumaking940', 1, 3),
#  ('pumaking940', 1, 4),
#  ('pumaking940', 2, 'original'),
#  ('pumaking940', 2, 0),
#  ('pumaking940', 2, 1),
#  ('pumaking940', 2, 2),
#  ('pumaking940', 2, 3),
#  ('pumaking940', 2, 4),
#  ('fishball0', 0, 'original'),
#  ('fishball0', 0, 0),
#  ('fishball0', 0, 1),
#  ('fishball0', 0, 2),
#  ('fishball0', 0, 3),
#  ('fishball0', 0, 4),
#  ('fishball0', 1, 'original'),
#  ('fishball0', 1, 0),
#  ('fishball0', 1, 1),
#  ('fishball0', 1, 2),
#  ('fishball0', 1, 3),
#  ('fishball0', 1, 4),
#  ('fishball0', 2, 'original'),
#  ('fishball0', 2, 0),
#  ('fishball0', 2, 1),
#  ('fishball0', 2, 2),
#  ('fishball0', 2, 3),
#  ('fishball0', 2, 4),
#  ('fishball0', 3, 'original'),
#  ('fishball0', 3, 0),
#  ('fishball0', 3, 1),
#  ('fishball0', 3, 2),
#  ('fishball0', 3, 3),
#  ('fishball0', 3, 4),
#  ('bbest0', 0, 'original'),
#  ('bbest0', 0, 0),
#  ('bbest0', 0, 1),
#  ('bbest0', 0, 2),
#  ('bbest0', 0, 3),
#  ('bbest0', 0, 4),
#  ('bbest0', 1, 'original'),
#  ('bbest0', 1, 0),
#  ('bbest0', 1, 1),
#  ('bbest0', 1, 2),
#  ('bbest0', 1, 3),
#  ('bbest0', 1, 4),
#  ('bbest0', 2, 'original'),
#  ('bbest0', 2, 0),
#  ('bbest0', 2, 1),
#  ('bbest0', 2, 2),
#  ('bbest0', 2, 3),
#  ('bbest0', 2, 4),
#  ('bbest0', 3, 'original'),
#  ('bbest0', 3, 0),
#  ('bbest0', 3, 1),
#  ('bbest0', 3, 2),
#  ('bbest0', 3, 3),
#  ('bbest0', 3, 4),
#  ('bbest0', 4, 'original'),
#  ('bbest0', 4, 0),
#  ('bbest0', 4, 1),
#  ('bbest0', 4, 2),
#  ('bbest0', 4, 3),
#  ('bbest0', 4, 4),
#  ('Kabie0', 0, 'original'),
#  ('Kabie0', 0, 0),
#  ('Kabie0', 0, 1),
#  ('Kabie0', 0, 2),
#  ('Kabie0', 0, 3),
#  ('Kabie0', 0, 4),
#  ('Kabie0', 1, 'original'),
#  ('Kabie0', 1, 0),
#  ('Kabie0', 1, 1),
#  ('Kabie0', 1, 2),
#  ('Kabie0', 1, 3),
#  ('Kabie0', 1, 4),
#  ('Kabie0', 2, 'original'),
#  ('Kabie0', 2, 0),
#  ('Kabie0', 2, 1),
#  ('Kabie0', 2, 2),
#  ('Kabie0', 2, 3),
#  ('Kabie0', 2, 4),
#  ('Kabie0', 3, 'original'),
#  ('Kabie0', 3, 0),
#  ('Kabie0', 3, 1),
#  ('Kabie0', 3, 2),
#  ('Kabie0', 3, 3),
#  ('Kabie0', 3, 4),
#  ('Kabie0', 4, 'original'),
#  ('Kabie0', 4, 0),
#  ('Kabie0', 4, 1),
#  ('Kabie0', 4, 2),
#  ('Kabie0', 4, 3),
#  ('Kabie0', 4, 4),
#  ('rlyeh0', 0, 'original'),
#  ('rlyeh0', 0, 0),
#  ('rlyeh0', 0, 1),
#  ('rlyeh0', 0, 2),
#  ('rlyeh0', 0, 3),
#  ('rlyeh0', 0, 4),
#  ('rlyeh0', 1, 'original'),
#  ('rlyeh0', 1, 0),
#  ('rlyeh0', 1, 1),
#  ('rlyeh0', 1, 2),
#  ('rlyeh0', 1, 3),
#  ('rlyeh0', 1, 4),
#  ('rlyeh0', 2, 'original'),
#  ('rlyeh0', 2, 0),
#  ('rlyeh0', 2, 1),
#  ('rlyeh0', 2, 2),
#  ('rlyeh0', 2, 3),
#  ('rlyeh0', 2, 4),
#  ('netsuso0', 0, 'original'),
#  ('netsuso0', 0, 0),
#  ('netsuso0', 0, 1),
#  ('netsuso0', 0, 2),
#  ('netsuso0', 0, 3),
#  ('netsuso0', 0, 4),
#  ('netsuso0', 1, 'original'),
#  ('netsuso0', 1, 0),
#  ('netsuso0', 1, 1),
#  ('netsuso0', 1, 2),
#  ('netsuso0', 1, 3),
#  ('netsuso0', 1, 4),
#  ('netsuso0', 2, 'original'),
#  ('netsuso0', 2, 0),
#  ('netsuso0', 2, 1),
#  ('netsuso0', 2, 2),
#  ('netsuso0', 2, 3),
#  ('netsuso0', 2, 4),
#  ('netsuso0', 3, 'original'),
#  ('netsuso0', 3, 0),
#  ('netsuso0', 3, 1),
#  ('netsuso0', 3, 2),
#  ('netsuso0', 3, 3),
#  ('netsuso0', 3, 4),
#  ('EricStansifer0', 0, 'original'),
#  ('EricStansifer0', 0, 0),
#  ('EricStansifer0', 0, 1),
#  ('EricStansifer0', 0, 2),
#  ('EricStansifer0', 0, 3),
#  ('EricStansifer0', 0, 4),
#  ('EricStansifer0', 1, 'original'),
#  ('EricStansifer0', 1, 0),
#  ('EricStansifer0', 1, 1),
#  ('EricStansifer0', 1, 2),
#  ('EricStansifer0', 1, 3),
#  ('EricStansifer0', 1, 4),
#  ('EricStansifer0', 2, 'original'),
#  ('EricStansifer0', 2, 0),
#  ('EricStansifer0', 2, 1),
#  ('EricStansifer0', 2, 2),
#  ('EricStansifer0', 2, 3),
#  ('EricStansifer0', 2, 4),
#  ('EricStansifer0', 3, 'original'),
#  ('EricStansifer0', 3, 0),
#  ('EricStansifer0', 3, 1),
#  ('EricStansifer0', 3, 2),
#  ('EricStansifer0', 3, 3),
#  ('EricStansifer0', 3, 4),
#  ('EricStansifer0', 4, 'original'),
#  ('EricStansifer0', 4, 0),
#  ('EricStansifer0', 4, 1),
#  ('EricStansifer0', 4, 2),
#  ('EricStansifer0', 4, 3),
#  ('EricStansifer0', 4, 4),
#  ('EricStansifer0', 5, 'original'),
#  ('EricStansifer0', 5, 0),
#  ('EricStansifer0', 5, 1),
#  ('EricStansifer0', 5, 2),
#  ('EricStansifer0', 5, 3),
#  ('EricStansifer0', 5, 4),
#  ('mitsukoh0', 0, 'original'),
#  ('mitsukoh0', 0, 0),
#  ('mitsukoh0', 0, 1),
#  ('mitsukoh0', 0, 2),
#  ('mitsukoh0', 0, 3),
#  ('mitsukoh0', 0, 4),
#  ('mitsukoh0', 1, 'original'),
#  ('mitsukoh0', 1, 0),
#  ('mitsukoh0', 1, 1),
#  ('mitsukoh0', 1, 2),
#  ('mitsukoh0', 1, 3),
#  ('mitsukoh0', 1, 4),
#  ('mitsukoh0', 2, 'original'),
#  ('mitsukoh0', 2, 0),
#  ('mitsukoh0', 2, 1),
#  ('mitsukoh0', 2, 2),
#  ('mitsukoh0', 2, 3),
#  ('mitsukoh0', 2, 4),
#  ('mitsukoh0', 3, 'original'),
#  ('mitsukoh0', 3, 0),
#  ('mitsukoh0', 3, 1),
#  ('mitsukoh0', 3, 2),
#  ('mitsukoh0', 3, 3),
#  ('mitsukoh0', 3, 4),
#  ('Wanseira0', 0, 'original'),
#  ('Wanseira0', 0, 0),
#  ('Wanseira0', 0, 1),
#  ('Wanseira0', 0, 2),
#  ('Wanseira0', 0, 3),
#  ('Wanseira0', 0, 4),
#  ('Wanseira0', 1, 'original'),
#  ('Wanseira0', 1, 0),
#  ('Wanseira0', 1, 1),
#  ('Wanseira0', 1, 2),
#  ('Wanseira0', 1, 3),
#  ('Wanseira0', 1, 4),
#  ('Wanseira0', 2, 'original'),
#  ('Wanseira0', 2, 0),
#  ('Wanseira0', 2, 1),
#  ('Wanseira0', 2, 2),
#  ('Wanseira0', 2, 3),
#  ('Wanseira0', 2, 4),
#  ('kumarsaurabh0', 0, 'original'),
#  ('kumarsaurabh0', 0, 0),
#  ('kumarsaurabh0', 0, 1),
#  ('kumarsaurabh0', 0, 2),
#  ('kumarsaurabh0', 0, 3),
#  ('kumarsaurabh0', 0, 4),
#  ('kumarsaurabh0', 1, 'original'),
#  ('kumarsaurabh0', 1, 0),
#  ('kumarsaurabh0', 1, 1),
#  ('kumarsaurabh0', 1, 2),
#  ('kumarsaurabh0', 1, 3),
#  ('kumarsaurabh0', 1, 4),
#  ('kumarsaurabh0', 2, 'original'),
#  ('kumarsaurabh0', 2, 0),
#  ('kumarsaurabh0', 2, 1),
#  ('kumarsaurabh0', 2, 2),
#  ('kumarsaurabh0', 2, 3),
#  ('kumarsaurabh0', 2, 4),
#  ('kumarsaurabh0', 3, 'original'),
#  ('kumarsaurabh0', 3, 0),
#  ('kumarsaurabh0', 3, 1),
#  ('kumarsaurabh0', 3, 2),
#  ('kumarsaurabh0', 3, 3),
#  ('kumarsaurabh0', 3, 4),
#  ('alexamici0', 0, 'original'),
#  ('alexamici0', 0, 0),
#  ('alexamici0', 0, 1),
#  ('alexamici0', 0, 2),
#  ('alexamici0', 0, 3),
#  ('alexamici0', 0, 4),
#  ('alexamici0', 1, 'original'),
#  ('alexamici0', 1, 0),
#  ('alexamici0', 1, 1),
#  ('alexamici0', 1, 2),
#  ('alexamici0', 1, 3),
#  ('alexamici0', 1, 4),
#  ('alexamici0', 2, 'original'),
#  ('alexamici0', 2, 0),
#  ('alexamici0', 2, 1),
#  ('alexamici0', 2, 2),
#  ('alexamici0', 2, 3),
#  ('alexamici0', 2, 4),
#  ('alexamici0', 3, 'original'),
#  ('alexamici0', 3, 0),
#  ('alexamici0', 3, 1),
#  ('alexamici0', 3, 2),
#  ('alexamici0', 3, 3),
#  ('alexamici0', 3, 4),
#  ('j4b0', 0, 'original'),
#  ('j4b0', 0, 0),
#  ('j4b0', 0, 1),
#  ('j4b0', 0, 2),
#  ('j4b0', 0, 3),
#  ('j4b0', 0, 4),
#  ('j4b0', 1, 'original'),
#  ('j4b0', 1, 0),
#  ('j4b0', 1, 1),
#  ('j4b0', 1, 2),
#  ('j4b0', 1, 3),
#  ('j4b0', 1, 4),
#  ('j4b0', 2, 'original'),
#  ('j4b0', 2, 0),
#  ('j4b0', 2, 1),
#  ('j4b0', 2, 2),
#  ('j4b0', 2, 3),
#  ('j4b0', 2, 4),
#  ('j4b0', 3, 'original'),
#  ('j4b0', 3, 0),
#  ('j4b0', 3, 1),
#  ('j4b0', 3, 2),
#  ('j4b0', 3, 3),
#  ('j4b0', 3, 4),
#  ('j4b0', 4, 'original'),
#  ('j4b0', 4, 0),
#  ('j4b0', 4, 1),
#  ('j4b0', 4, 2),
#  ('j4b0', 4, 3),
#  ('j4b0', 4, 4),
#  ('shastri0', 0, 'original'),
#  ('shastri0', 0, 0),
#  ('shastri0', 0, 1),
#  ('shastri0', 0, 2),
#  ('shastri0', 0, 3),
#  ('shastri0', 0, 4),
#  ('shastri0', 1, 'original'),
#  ('shastri0', 1, 0),
#  ('shastri0', 1, 1),
#  ('shastri0', 1, 2),
#  ('shastri0', 1, 3),
#  ('shastri0', 1, 4),
#  ('shastri0', 2, 'original'),
#  ('shastri0', 2, 0),
#  ('shastri0', 2, 1),
#  ('shastri0', 2, 2),
#  ('shastri0', 2, 3),
#  ('shastri0', 2, 4),
#  ('shastri0', 3, 'original'),
#  ('shastri0', 3, 0),
#  ('shastri0', 3, 1),
#  ('shastri0', 3, 2),
#  ('shastri0', 3, 3),
#  ('shastri0', 3, 4),
#  ('shastri0', 4, 'original'),
#  ('shastri0', 4, 0),
#  ('shastri0', 4, 1),
#  ('shastri0', 4, 2),
#  ('shastri0', 4, 3),
#  ('shastri0', 4, 4),
#  ('brad0', 0, 'original'),
#  ('brad0', 0, 0),
#  ('brad0', 0, 1),
#  ('brad0', 0, 2),
#  ('brad0', 0, 3),
#  ('brad0', 0, 4),
#  ('brad0', 1, 'original'),
#  ('brad0', 1, 0),
#  ('brad0', 1, 1),
#  ('brad0', 1, 2),
#  ('brad0', 1, 3),
#  ('brad0', 1, 4),
#  ('brad0', 2, 'original'),
#  ('brad0', 2, 0),
#  ('brad0', 2, 1),
#  ('brad0', 2, 2),
#  ('brad0', 2, 3),
#  ('brad0', 2, 4),
#  ('brad0', 3, 'original'),
#  ('brad0', 3, 0),
#  ('brad0', 3, 1),
#  ('brad0', 3, 2),
#  ('brad0', 3, 3),
#  ('brad0', 3, 4),
#  ('brad0', 4, 'original'),
#  ('brad0', 4, 0),
#  ('brad0', 4, 1),
#  ('brad0', 4, 2),
#  ('brad0', 4, 3),
#  ('brad0', 4, 4),
#  ('xithan0', 0, 'original'),
#  ('xithan0', 0, 0),
#  ('xithan0', 0, 1),
#  ('xithan0', 0, 2),
#  ('xithan0', 0, 3),
#  ('xithan0', 0, 4),
#  ('xithan0', 1, 'original'),
#  ('xithan0', 1, 0),
#  ('xithan0', 1, 1),
#  ('xithan0', 1, 2),
#  ('xithan0', 1, 3),
#  ('xithan0', 1, 4),
#  ('xithan0', 2, 'original'),
#  ('xithan0', 2, 0),
#  ('xithan0', 2, 1),
#  ('xithan0', 2, 2),
#  ('xithan0', 2, 3),
#  ('xithan0', 2, 4),
#  ('xithan0', 3, 'original'),
#  ('xithan0', 3, 0),
#  ('xithan0', 3, 1),
#  ('xithan0', 3, 2),
#  ('xithan0', 3, 3),
#  ('xithan0', 3, 4),
#  ('dozingcat0', 0, 'original'),
#  ('dozingcat0', 0, 0),
#  ('dozingcat0', 0, 1),
#  ('dozingcat0', 0, 2),
#  ('dozingcat0', 0, 3),
#  ('dozingcat0', 0, 4),
#  ('dozingcat0', 1, 'original'),
#  ('dozingcat0', 1, 0),
#  ('dozingcat0', 1, 1),
#  ('dozingcat0', 1, 2),
#  ('dozingcat0', 1, 3),
#  ('dozingcat0', 1, 4),
#  ('dozingcat0', 2, 'original'),
#  ('dozingcat0', 2, 0),
#  ('dozingcat0', 2, 1),
#  ('dozingcat0', 2, 2),
#  ('dozingcat0', 2, 3),
#  ('dozingcat0', 2, 4),
#  ('dozingcat0', 3, 'original'),
#  ('dozingcat0', 3, 0),
#  ('dozingcat0', 3, 1),
#  ('dozingcat0', 3, 2),
#  ('dozingcat0', 3, 3),
#  ('dozingcat0', 3, 4),
#  ('dozingcat0', 4, 'original'),
#  ('dozingcat0', 4, 0),
#  ('dozingcat0', 4, 1),
#  ('dozingcat0', 4, 2),
#  ('dozingcat0', 4, 3),
#  ('dozingcat0', 4, 4),
#  ('cocoatomo0', 0, 'original'),
#  ('cocoatomo0', 0, 0),
#  ('cocoatomo0', 0, 1),
#  ('cocoatomo0', 0, 2),
#  ('cocoatomo0', 0, 3),
#  ('cocoatomo0', 0, 4),
#  ('cocoatomo0', 1, 'original'),
#  ('cocoatomo0', 1, 0),
#  ('cocoatomo0', 1, 1),
#  ('cocoatomo0', 1, 2),
#  ('cocoatomo0', 1, 3),
#  ('cocoatomo0', 1, 4),
#  ('cocoatomo0', 2, 'original'),
#  ('cocoatomo0', 2, 0),
#  ('cocoatomo0', 2, 1),
#  ('cocoatomo0', 2, 2),
#  ('cocoatomo0', 2, 3),
#  ('cocoatomo0', 2, 4),
#  ('cocoatomo0', 3, 'original'),
#  ('cocoatomo0', 3, 0),
#  ('cocoatomo0', 3, 1),
#  ('cocoatomo0', 3, 2),
#  ('cocoatomo0', 3, 3),
#  ('cocoatomo0', 3, 4),
#  ('dkirienko0', 0, 'original'),
#  ('dkirienko0', 0, 0),
#  ('dkirienko0', 0, 1),
#  ('dkirienko0', 0, 2),
#  ('dkirienko0', 0, 3),
#  ('dkirienko0', 0, 4),
#  ('dkirienko0', 1, 'original'),
#  ('dkirienko0', 1, 0),
#  ('dkirienko0', 1, 1),
#  ('dkirienko0', 1, 2),
#  ('dkirienko0', 1, 3),
#  ('dkirienko0', 1, 4),
#  ('dkirienko0', 2, 'original'),
#  ('dkirienko0', 2, 0),
#  ('dkirienko0', 2, 1),
#  ('dkirienko0', 2, 2),
#  ('dkirienko0', 2, 3),
#  ('dkirienko0', 2, 4),
#  ('dkirienko0', 3, 'original'),
#  ('dkirienko0', 3, 0),
#  ('dkirienko0', 3, 1),
#  ('dkirienko0', 3, 2),
#  ('dkirienko0', 3, 3),
#  ('dkirienko0', 3, 4),
#  ('dkirienko0', 4, 'original'),
#  ('dkirienko0', 4, 0),
#  ('dkirienko0', 4, 1),
#  ('dkirienko0', 4, 2),
#  ('dkirienko0', 4, 3),
#  ('dkirienko0', 4, 4),
#  ('ali.assaf0', 0, 'original'),
#  ('ali.assaf0', 0, 0),
#  ('ali.assaf0', 0, 1),
#  ('ali.assaf0', 0, 2),
#  ('ali.assaf0', 0, 3),
#  ('ali.assaf0', 0, 4),
#  ('ali.assaf0', 1, 'original'),
#  ('ali.assaf0', 1, 0),
#  ('ali.assaf0', 1, 1),
#  ('ali.assaf0', 1, 2),
#  ('ali.assaf0', 1, 3),
#  ('ali.assaf0', 1, 4),
#  ('ali.assaf0', 2, 'original'),
#  ('ali.assaf0', 2, 0),
#  ('ali.assaf0', 2, 1),
#  ('ali.assaf0', 2, 2),
#  ('ali.assaf0', 2, 3),
#  ('ali.assaf0', 2, 4),
#  ('ali.assaf0', 3, 'original'),
#  ('ali.assaf0', 3, 0),
#  ('ali.assaf0', 3, 1),
#  ('ali.assaf0', 3, 2),
#  ('ali.assaf0', 3, 3),
#  ('ali.assaf0', 3, 4),
#  ('ali.assaf0', 4, 'original'),
#  ('ali.assaf0', 4, 0),
#  ('ali.assaf0', 4, 1),
#  ('ali.assaf0', 4, 2),
#  ('ali.assaf0', 4, 3),
#  ('ali.assaf0', 4, 4),
#  ('ali.assaf0', 5, 'original'),
#  ('ali.assaf0', 5, 0),
#  ('ali.assaf0', 5, 1),
#  ('ali.assaf0', 5, 2),
#  ('ali.assaf0', 5, 3),
#  ('ali.assaf0', 5, 4),
#  ('ali.assaf0', 6, 'original'),
#  ('ali.assaf0', 6, 0),
#  ('ali.assaf0', 6, 1),
#  ('ali.assaf0', 6, 2),
#  ('ali.assaf0', 6, 3),
#  ('ali.assaf0', 6, 4),
#  ('ali.assaf0', 7, 'original'),
#  ('ali.assaf0', 7, 0),
#  ('ali.assaf0', 7, 1),
#  ('ali.assaf0', 7, 2),
#  ('ali.assaf0', 7, 3),
#  ('ali.assaf0', 7, 4),
#  ('ali.assaf0', 8, 'original'),
#  ('ali.assaf0', 8, 0),
#  ('ali.assaf0', 8, 1),
#  ('ali.assaf0', 8, 2),
#  ('ali.assaf0', 8, 3),
#  ('ali.assaf0', 8, 4),
#  ('ali.assaf0', 9, 'original'),
#  ('ali.assaf0', 9, 0),
#  ('ali.assaf0', 9, 1),
#  ('ali.assaf0', 9, 2),
#  ('ali.assaf0', 9, 3),
#  ('ali.assaf0', 9, 4),
#  ('FatAlex0', 0, 'original'),
#  ('FatAlex0', 0, 0),
#  ('FatAlex0', 0, 1),
#  ('FatAlex0', 0, 2),
#  ('FatAlex0', 0, 3),
#  ('FatAlex0', 0, 4),
#  ('FatAlex0', 1, 'original'),
#  ('FatAlex0', 1, 0),
#  ('FatAlex0', 1, 1),
#  ('FatAlex0', 1, 2),
#  ('FatAlex0', 1, 3),
#  ('FatAlex0', 1, 4),
#  ('FatAlex0', 2, 'original'),
#  ('FatAlex0', 2, 0),
#  ('FatAlex0', 2, 1),
#  ('FatAlex0', 2, 2),
#  ('FatAlex0', 2, 3),
#  ('FatAlex0', 2, 4),
#  ('FatAlex0', 3, 'original'),
#  ('FatAlex0', 3, 0),
#  ('FatAlex0', 3, 1),
#  ('FatAlex0', 3, 2),
#  ('FatAlex0', 3, 3),
#  ('FatAlex0', 3, 4),
#  ('Sp30000', 0, 'original'),
#  ('Sp30000', 0, 0),
#  ('Sp30000', 0, 1),
#  ('Sp30000', 0, 2),
#  ('Sp30000', 0, 3),
#  ('Sp30000', 0, 4),
#  ('Sp30000', 1, 'original'),
#  ('Sp30000', 1, 0),
#  ('Sp30000', 1, 1),
#  ('Sp30000', 1, 2),
#  ('Sp30000', 1, 3),
#  ('Sp30000', 1, 4),
#  ('Sp30000', 2, 'original'),
#  ('Sp30000', 2, 0),
#  ('Sp30000', 2, 1),
#  ('Sp30000', 2, 2),
#  ('Sp30000', 2, 3),
#  ('Sp30000', 2, 4),
#  ('Sp30000', 3, 'original'),
#  ('Sp30000', 3, 0),
#  ('Sp30000', 3, 1),
#  ('Sp30000', 3, 2),
#  ('Sp30000', 3, 3),
#  ('Sp30000', 3, 4),
#  ('Sp30000', 4, 'original'),
#  ('Sp30000', 4, 0),
#  ('Sp30000', 4, 1),
#  ('Sp30000', 4, 2),
#  ('Sp30000', 4, 3),
#  ('Sp30000', 4, 4),
#  ('Sp30000', 5, 'original'),
#  ('Sp30000', 5, 0),
#  ('Sp30000', 5, 1),
#  ('Sp30000', 5, 2),
#  ('Sp30000', 5, 3),
#  ('Sp30000', 5, 4),
#  ('jgaten0', 0, 'original'),
#  ('jgaten0', 0, 0),
#  ('jgaten0', 0, 1),
#  ('jgaten0', 0, 2),
#  ('jgaten0', 0, 3),
#  ('jgaten0', 0, 4),
#  ('jgaten0', 1, 'original'),
#  ('jgaten0', 1, 0),
#  ('jgaten0', 1, 1),
#  ('jgaten0', 1, 2),
#  ('jgaten0', 1, 3),
#  ('jgaten0', 1, 4),
#  ('jgaten0', 2, 'original'),
#  ('jgaten0', 2, 0),
#  ('jgaten0', 2, 1),
#  ('jgaten0', 2, 2),
#  ('jgaten0', 2, 3),
#  ('jgaten0', 2, 4),
#  ('jgaten0', 3, 'original'),
#  ('jgaten0', 3, 0),
#  ('jgaten0', 3, 1),
#  ('jgaten0', 3, 2),
#  ('jgaten0', 3, 3),
#  ('jgaten0', 3, 4),
#  ('jgaten0', 4, 'original'),
#  ('jgaten0', 4, 0),
#  ('jgaten0', 4, 1),
#  ('jgaten0', 4, 2),
#  ('jgaten0', 4, 3),
#  ('jgaten0', 4, 4),
#  ('ssssss0', 0, 'original'),
#  ('ssssss0', 0, 0),
#  ('ssssss0', 0, 1),
#  ('ssssss0', 0, 2),
#  ('ssssss0', 0, 3),
#  ('ssssss0', 0, 4),
#  ('ssssss0', 1, 'original'),
#  ('ssssss0', 1, 0),
#  ('ssssss0', 1, 1),
#  ('ssssss0', 1, 2),
#  ('ssssss0', 1, 3),
#  ('ssssss0', 1, 4),
#  ('ssssss0', 2, 'original'),
#  ('ssssss0', 2, 0),
#  ('ssssss0', 2, 1),
#  ('ssssss0', 2, 2),
#  ('ssssss0', 2, 3),
#  ('ssssss0', 2, 4),
#  ('ssssss0', 3, 'original'),
#  ('ssssss0', 3, 0),
#  ('ssssss0', 3, 1),
#  ('ssssss0', 3, 2),
#  ('ssssss0', 3, 3),
#  ('ssssss0', 3, 4),
#  ('ssssss0', 4, 'original'),
#  ('ssssss0', 4, 0),
#  ('ssssss0', 4, 1),
#  ('ssssss0', 4, 2),
#  ('ssssss0', 4, 3),
#  ('ssssss0', 4, 4),
#  ('YOBA0', 0, 'original'),
#  ('YOBA0', 0, 0),
#  ('YOBA0', 0, 1),
#  ('YOBA0', 0, 2),
#  ('YOBA0', 0, 3),
#  ('YOBA0', 0, 4),
#  ('YOBA0', 1, 'original'),
#  ('YOBA0', 1, 0),
#  ('YOBA0', 1, 1),
#  ('YOBA0', 1, 2),
#  ('YOBA0', 1, 3),
#  ('YOBA0', 1, 4),
#  ('YOBA0', 2, 'original'),
#  ('YOBA0', 2, 0),
#  ('YOBA0', 2, 1),
#  ('YOBA0', 2, 2),
#  ('YOBA0', 2, 3),
#  ('YOBA0', 2, 4),
#  ('mariusd0', 0, 'original'),
#  ('mariusd0', 0, 0),
#  ('mariusd0', 0, 1),
#  ('mariusd0', 0, 2),
#  ('mariusd0', 0, 3),
#  ('mariusd0', 0, 4),
#  ('mariusd0', 1, 'original'),
#  ('mariusd0', 1, 0),
#  ('mariusd0', 1, 1),
#  ('mariusd0', 1, 2),
#  ('mariusd0', 1, 3),
#  ('mariusd0', 1, 4),
#  ('mariusd0', 2, 'original'),
#  ('mariusd0', 2, 0),
#  ('mariusd0', 2, 1),
#  ('mariusd0', 2, 2),
#  ('mariusd0', 2, 3),
#  ('mariusd0', 2, 4),
#  ('Shurick0', 0, 'original'),
#  ('Shurick0', 0, 0),
#  ('Shurick0', 0, 1),
#  ('Shurick0', 0, 2),
#  ('Shurick0', 0, 3),
#  ('Shurick0', 0, 4),
#  ('Shurick0', 1, 'original'),
#  ('Shurick0', 1, 0),
#  ('Shurick0', 1, 1),
#  ('Shurick0', 1, 2),
#  ('Shurick0', 1, 3),
#  ('Shurick0', 1, 4),
#  ('Shurick0', 2, 'original'),
#  ('Shurick0', 2, 0),
#  ('Shurick0', 2, 1),
#  ('Shurick0', 2, 2),
#  ('Shurick0', 2, 3),
#  ('Shurick0', 2, 4),
#  ('ChrisJ0', 0, 'original'),
#  ('ChrisJ0', 0, 0),
#  ('ChrisJ0', 0, 1),
#  ('ChrisJ0', 0, 2),
#  ('ChrisJ0', 0, 3),
#  ('ChrisJ0', 0, 4),
#  ('ChrisJ0', 1, 'original'),
#  ('ChrisJ0', 1, 0),
#  ('ChrisJ0', 1, 1),
#  ('ChrisJ0', 1, 2),
#  ('ChrisJ0', 1, 3),
#  ('ChrisJ0', 1, 4),
#  ('ChrisJ0', 2, 'original'),
#  ('ChrisJ0', 2, 0),
#  ('ChrisJ0', 2, 1),
#  ('ChrisJ0', 2, 2),
#  ('ChrisJ0', 2, 3),
#  ('ChrisJ0', 2, 4),
#  ('GauravRai0', 0, 'original'),
#  ('GauravRai0', 0, 0),
#  ('GauravRai0', 0, 1),
#  ('GauravRai0', 0, 2),
#  ('GauravRai0', 0, 3),
#  ('GauravRai0', 0, 4),
#  ('GauravRai0', 1, 'original'),
#  ('GauravRai0', 1, 0),
#  ('GauravRai0', 1, 1),
#  ('GauravRai0', 1, 2),
#  ('GauravRai0', 1, 3),
#  ('GauravRai0', 1, 4),
#  ('GauravRai0', 2, 'original'),
#  ('GauravRai0', 2, 0),
#  ('GauravRai0', 2, 1),
#  ('GauravRai0', 2, 2),
#  ('GauravRai0', 2, 3),
#  ('GauravRai0', 2, 4),
#  ('GauravRai0', 3, 'original'),
#  ('GauravRai0', 3, 0),
#  ('GauravRai0', 3, 1),
#  ('GauravRai0', 3, 2),
#  ('GauravRai0', 3, 3),
#  ('GauravRai0', 3, 4),
#  ('GauravRai0', 4, 'original'),
#  ('GauravRai0', 4, 0),
#  ('GauravRai0', 4, 1),
#  ('GauravRai0', 4, 2),
#  ('GauravRai0', 4, 3),
#  ('GauravRai0', 4, 4),
#  ('elffikk0', 0, 'original'),
#  ('elffikk0', 0, 0),
#  ('elffikk0', 0, 1),
#  ('elffikk0', 0, 2),
#  ('elffikk0', 0, 3),
#  ('elffikk0', 0, 4),
#  ('elffikk0', 1, 'original'),
#  ('elffikk0', 1, 0),
#  ('elffikk0', 1, 1),
#  ('elffikk0', 1, 2),
#  ...]

# %%
cur = validation_result[1]
for row_id, row in enumerate(cur['sim']):
    asort = (-row).argsort()
    best = asort[1]
    
    print(cur['back_indices'][row_id], cur['back_indices'][best])
# Out:
# ('pawko0', 0, 'original') ('argusdusty0', 0, 3)
# ('pawko0', 0, 0) ('argusdusty0', 2, 0)
# ('pawko0', 0, 1) ('pawko0', 6, 'original')
# ('pawko0', 0, 2) ('pawko0', 4, 1)
# ('pawko0', 0, 3) ('pawko0', 4, 1)
# ('pawko0', 0, 4) ('Bugloon0', 3, 1)
# ('pawko0', 1, 'original') ('mgiuca0', 1, 3)
# ('pawko0', 1, 0) ('pawko0', 2, 4)
# ('pawko0', 1, 1) ('pawko0', 4, 3)
# ('pawko0', 1, 2) ('barryd0', 0, 2)
# ('pawko0', 1, 3) ('mgiuca0', 1, 4)
# ('pawko0', 1, 4) ('FatAlex0', 3, 2)
# ('pawko0', 2, 'original') ('bbest0', 3, 2)
# ('pawko0', 2, 0) ('argusdusty0', 0, 4)
# ('pawko0', 2, 1) ('bigOnion0', 1, 'original')
# ('pawko0', 2, 2) ('nobodyisme0', 4, 1)
# ('pawko0', 2, 3) ('bbest0', 3, 2)
# ('pawko0', 2, 4) ('pawko0', 0, 0)
# ('pawko0', 3, 'original') ('pawko0', 7, 'original')
# ('pawko0', 3, 0) ('VuryLeo0', 1, 3)
# ('pawko0', 3, 1) ('bbest0', 3, 2)
# ('pawko0', 3, 2) ('argusdusty0', 3, 1)
# ('pawko0', 3, 3) ('pawko0', 6, 3)
# ('pawko0', 3, 4) ('SAPikachu0', 3, 2)
# ('pawko0', 4, 'original') ('pawko0', 4, 1)
# ('pawko0', 4, 0) ('pawko0', 7, 'original')
# ('pawko0', 4, 1) ('pawko0', 5, 'original')
# ('pawko0', 4, 2) ('pawko0', 1, 'original')
# ('pawko0', 4, 3) ('pawko0', 7, 'original')
# ('pawko0', 4, 4) ('pawko0', 4, 1)
# ('pawko0', 5, 'original') ('bbest0', 3, 2)
# ('pawko0', 5, 0) ('j4b0', 1, 4)
# ('pawko0', 5, 1) ('bbest0', 1, 4)
# ('pawko0', 5, 2) ('FatAlex0', 3, 2)
# ('pawko0', 5, 3) ('bbest0', 2, 0)
# ('pawko0', 5, 4) ('Fizu0', 2, 0)
# ('pawko0', 6, 'original') ('pawko0', 0, 1)
# ('pawko0', 6, 0) ('kumarsaurabh0', 0, 3)
# ('pawko0', 6, 1) ('bigOnion0', 2, 2)
# ('pawko0', 6, 2) ('voidus0', 2, 1)
# ('pawko0', 6, 3) ('pawko0', 5, 4)
# ('pawko0', 6, 4) ('cocoatomo0', 2, 1)
# ('pawko0', 7, 'original') ('pawko0', 4, 3)
# ('pawko0', 7, 0) ('KennethUlrich0', 0, 1)
# ('pawko0', 7, 1) ('waitingkuo05270', 2, 2)
# ('pawko0', 7, 2) ('pawko0', 4, 1)
# ('pawko0', 7, 3) ('pawko0', 5, 'original')
# ('pawko0', 7, 4) ('pawko0', 3, 4)
# ('Jethol0', 0, 'original') ('Jethol0', 2, 'original')
# ('Jethol0', 0, 0) ('KennethUlrich0', 3, 1)
# ('Jethol0', 0, 1) ('KennethUlrich0', 1, 'original')
# ('Jethol0', 0, 2) ('j4b0', 4, 2)
# ('Jethol0', 0, 3) ('alexamici0', 1, 'original')
# ('Jethol0', 0, 4) ('Bugloon0', 0, 3)
# ('Jethol0', 1, 'original') ('Jethol0', 1, 0)
# ('Jethol0', 1, 0) ('Jethol0', 1, 'original')
# ('Jethol0', 1, 1) ('jgaten0', 2, 3)
# ('Jethol0', 1, 2) ('alexamici0', 1, 1)
# ('Jethol0', 1, 3) ('farin0', 2, 3)
# ('Jethol0', 1, 4) ('j4b0', 4, 4)
# ('Jethol0', 2, 'original') ('KennethUlrich0', 3, 1)
# ('Jethol0', 2, 0) ('KennethUlrich0', 3, 1)
# ('Jethol0', 2, 1) ('mgiuca0', 0, 'original')
# ('Jethol0', 2, 2) ('pawko0', 5, 1)
# ('Jethol0', 2, 3) ('waitingkuo05270', 1, 1)
# ('Jethol0', 2, 4) ('argusdusty0', 2, 2)
# ('pablo.t890', 0, 'original') ('pablo.t890', 0, 3)
# ('pablo.t890', 0, 0) ('FatAlex0', 3, 0)
# ('pablo.t890', 0, 1) ('zerodot0', 0, 1)
# ('pablo.t890', 0, 2) ('mth0', 1, 0)
# ('pablo.t890', 0, 3) ('pablo.t890', 0, 2)
# ('pablo.t890', 0, 4) ('mth0', 3, 2)
# ('pablo.t890', 1, 'original') ('FatAlex0', 3, 2)
# ('pablo.t890', 1, 0) ('zerodot0', 1, 0)
# ('pablo.t890', 1, 1) ('d.operator0', 0, 3)
# ('pablo.t890', 1, 2) ('KennethUlrich0', 1, 'original')
# ('pablo.t890', 1, 3) ('pawko0', 2, 'original')
# ('pablo.t890', 1, 4) ('d.operator0', 0, 4)
# ('pablo.t890', 2, 'original') ('BlueFish0', 1, 4)
# ('pablo.t890', 2, 0) ('Koumes210', 4, 0)
# ('pablo.t890', 2, 1) ('ssssss0', 0, 'original')
# ('pablo.t890', 2, 2) ('brad0', 2, 1)
# ('pablo.t890', 2, 3) ('hector.zhao0', 1, 4)
# ('pablo.t890', 2, 4) ('diver0', 2, 0)
# ('pablo.t890', 3, 'original') ('d.operator0', 0, 0)
# ('pablo.t890', 3, 0) ('farin0', 0, 3)
# ('pablo.t890', 3, 1) ('FatAlex0', 3, 2)
# ('pablo.t890', 3, 2) ('Kabie0', 2, 3)
# ('pablo.t890', 3, 3) ('mth0', 2, 3)
# ('pablo.t890', 3, 4) ('j4b0', 4, 2)
# ('pablo.t890', 4, 'original') ('gsz0', 1, 4)
# ('pablo.t890', 4, 0) ('argusdusty0', 3, 1)
# ('pablo.t890', 4, 1) ('mgiuca0', 1, 3)
# ('pablo.t890', 4, 2) ('waitingkuo05270', 2, 4)
# ('pablo.t890', 4, 3) ('ali.assaf0', 1, 1)
# ('pablo.t890', 4, 4) ('argusdusty0', 1, 'original')
# ('d.operator0', 0, 'original') ('waitingkuo05270', 1, 1)
# ('d.operator0', 0, 0) ('d.operator0', 0, 3)
# ('d.operator0', 0, 1) ('KennethUlrich0', 2, 'original')
# ('d.operator0', 0, 2) ('FatAlex0', 3, 2)
# ('d.operator0', 0, 3) ('dareonion0', 1, 1)
# ('d.operator0', 0, 4) ('dareonion0', 1, 1)
# ('d.operator0', 1, 'original') ('waynerad0', 2, 'original')
# ('d.operator0', 1, 0) ('zerodot0', 1, 2)
# ('d.operator0', 1, 1) ('damo.yu0', 4, 0)
# ('d.operator0', 1, 2) ('waynerad0', 1, 'original')
# ('d.operator0', 1, 3) ('FatAlex0', 3, 3)
# ('d.operator0', 1, 4) ('FatAlex0', 1, 2)
# ('d.operator0', 2, 'original') ('d.operator0', 2, 1)
# ('d.operator0', 2, 0) ('killerrex0', 2, 0)
# ('d.operator0', 2, 1) ('d.operator0', 2, 4)
# ('d.operator0', 2, 2) ('d.operator0', 2, 1)
# ('d.operator0', 2, 3) ('d.operator0', 2, 1)
# ('d.operator0', 2, 4) ('d.operator0', 2, 1)
# ('d.operator0', 3, 'original') ('d.operator0', 6, 4)
# ('d.operator0', 3, 0) ('VuryLeo0', 0, 3)
# ('d.operator0', 3, 1) ('d.operator0', 6, 'original')
# ('d.operator0', 3, 2) ('JustinKang0', 2, 4)
# ('d.operator0', 3, 3) ('dareonion0', 4, 4)
# ('d.operator0', 3, 4) ('Simozene0', 0, 4)
# ('d.operator0', 4, 'original') ('d.operator0', 4, 2)
# ('d.operator0', 4, 0) ('damo.yu0', 4, 4)
# ('d.operator0', 4, 1) ('mth0', 6, 2)
# ('d.operator0', 4, 2) ('d.operator0', 4, 3)
# ('d.operator0', 4, 3) ('d.operator0', 4, 2)
# ('d.operator0', 4, 4) ('bigOnion0', 7, 0)
# ('d.operator0', 5, 'original') ('ali.assaf0', 0, 4)
# ('d.operator0', 5, 0) ('d.operator0', 0, 3)
# ('d.operator0', 5, 1) ('kumarsaurabh0', 3, 0)
# ('d.operator0', 5, 2) ('mgiuca0', 0, 'original')
# ('d.operator0', 5, 3) ('damo.yu0', 4, 4)
# ('d.operator0', 5, 4) ('dareonion0', 4, 3)
# ('d.operator0', 6, 'original') ('bigOnion0', 0, 2)
# ('d.operator0', 6, 0) ('lidaobing0', 3, 2)
# ('d.operator0', 6, 1) ('d.operator0', 6, 4)
# ('d.operator0', 6, 2) ('bigOnion0', 0, 2)
# ('d.operator0', 6, 3) ('d.operator0', 3, 2)
# ('d.operator0', 6, 4) ('d.operator0', 6, 1)
# ('ana.valeije0', 0, 'original') ('Sibi0', 2, 'original')
# ('ana.valeije0', 0, 0) ('GauravRai0', 0, 1)
# ('ana.valeije0', 0, 1) ('ana.valeije0', 0, 'original')
# ('ana.valeije0', 0, 2) ('nrpeterson0', 3, 'original')
# ('ana.valeije0', 0, 3) ('Taizo0', 2, 'original')
# ('ana.valeije0', 0, 4) ('damo.yu0', 2, 'original')
# ('ana.valeije0', 1, 'original') ('damo.yu0', 1, 0)
# ('ana.valeije0', 1, 0) ('ana.valeije0', 1, 2)
# ('ana.valeije0', 1, 1) ('whaatt0', 0, 1)
# ('ana.valeije0', 1, 2) ('dkirienko0', 1, 'original')
# ('ana.valeije0', 1, 3) ('damo.yu0', 1, 'original')
# ('ana.valeije0', 1, 4) ('GauravRai0', 0, 1)
# ('ana.valeije0', 2, 'original') ('pumaking940', 0, 0)
# ('ana.valeije0', 2, 0) ('ana.valeije0', 2, 2)
# ('ana.valeije0', 2, 1) ('ana.valeije0', 2, 2)
# ('ana.valeije0', 2, 2) ('ana.valeije0', 2, 4)
# ('ana.valeije0', 2, 3) ('ana.valeije0', 2, 2)
# ('ana.valeije0', 2, 4) ('ana.valeije0', 2, 2)
# ('ana.valeije0', 3, 'original') ('GauravRai0', 4, 3)
# ('ana.valeije0', 3, 0) ('GauravRai0', 4, 'original')
# ('ana.valeije0', 3, 1) ('GauravRai0', 1, 2)
# ('ana.valeije0', 3, 2) ('GauravRai0', 0, 1)
# ('ana.valeije0', 3, 3) ('ana.valeije0', 0, 0)
# ('ana.valeije0', 3, 4) ('GauravRai0', 0, 1)
# ('dareonion0', 0, 'original') ('gsz0', 1, 4)
# ('dareonion0', 0, 0) ('EricStansifer0', 1, 2)
# ('dareonion0', 0, 1) ('killerrex0', 5, 4)
# ('dareonion0', 0, 2) ('farin0', 2, 1)
# ('dareonion0', 0, 3) ('gsz0', 1, 4)
# ('dareonion0', 0, 4) ('rlyeh0', 2, 0)
# ('dareonion0', 1, 'original') ('argusdusty0', 0, 1)
# ('dareonion0', 1, 0) ('bbest0', 0, 'original')
# ('dareonion0', 1, 1) ('d.operator0', 0, 3)
# ('dareonion0', 1, 2) ('argusdusty0', 3, 0)
# ('dareonion0', 1, 3) ('FatAlex0', 3, 2)
# ('dareonion0', 1, 4) ('KennethUlrich0', 0, 0)
# ('dareonion0', 2, 'original') ('KennethUlrich0', 0, 0)
# ('dareonion0', 2, 0) ('zerodot0', 1, 0)
# ('dareonion0', 2, 1) ('j4b0', 4, 4)
# ('dareonion0', 2, 2) ('Kabie0', 0, 2)
# ('dareonion0', 2, 3) ('KennethUlrich0', 1, 2)
# ('dareonion0', 2, 4) ('EricStansifer0', 5, 2)
# ('dareonion0', 3, 'original') ('VuryLeo0', 1, 2)
# ('dareonion0', 3, 0) ('dareonion0', 3, 1)
# ('dareonion0', 3, 1) ('dareonion0', 3, 0)
# ('dareonion0', 3, 2) ('dareonion0', 4, 'original')
# ('dareonion0', 3, 3) ('falcon1123580', 2, 3)
# ('dareonion0', 3, 4) ('dareonion0', 4, 0)
# ('dareonion0', 4, 'original') ('dareonion0', 3, 2)
# ('dareonion0', 4, 0) ('waynerad0', 0, 4)
# ('dareonion0', 4, 1) ('dareonion0', 4, 4)
# ('dareonion0', 4, 2) ('nobodyisme0', 3, 1)
# ('dareonion0', 4, 3) ('d.operator0', 5, 4)
# ('dareonion0', 4, 4) ('dareonion0', 4, 1)
# ('farin0', 0, 'original') ('farin0', 3, 2)
# ('farin0', 0, 0) ('farin0', 0, 3)
# ('farin0', 0, 1) ('Bugloon0', 3, 2)
# ('farin0', 0, 2) ('Bugloon0', 0, 2)
# ('farin0', 0, 3) ('farin0', 0, 0)
# ('farin0', 0, 4) ('Bugloon0', 3, 0)
# ('farin0', 1, 'original') ('Tonto0', 1, 4)
# ('farin0', 1, 0) ('GauravRai0', 0, 1)
# ('farin0', 1, 1) ('damo.yu0', 1, 'original')
# ('farin0', 1, 2) ('GauravRai0', 4, 3)
# ('farin0', 1, 3) ('RudyGuillan0', 3, 4)
# ('farin0', 1, 4) ('GauravRai0', 0, 1)
# ('farin0', 2, 'original') ('bbest0', 2, 0)
# ('farin0', 2, 0) ('farin0', 2, 3)
# ('farin0', 2, 1) ('cocoatomo0', 1, 0)
# ('farin0', 2, 2) ('gsz0', 0, 0)
# ('farin0', 2, 3) ('d.operator0', 0, 'original')
# ('farin0', 2, 4) ('alexamici0', 1, 1)
# ('farin0', 3, 'original') ('Bugloon0', 0, 2)
# ('farin0', 3, 0) ('nobodyisme0', 1, 'original')
# ('farin0', 3, 1) ('kumarsaurabh0', 1, 4)
# ('farin0', 3, 2) ('Simozene0', 0, 2)
# ('farin0', 3, 3) ('cocoatomo0', 1, 3)
# ('farin0', 3, 4) ('voidus0', 3, 4)
# ('wheleph0', 0, 'original') ('peter.gtz0', 3, 3)
# ('wheleph0', 0, 0) ('Tonto0', 0, 0)
# ('wheleph0', 0, 1) ('Soloman0', 0, 'original')
# ('wheleph0', 0, 2) ('damo.yu0', 5, 'original')
# ('wheleph0', 0, 3) ('Ardem0', 0, 3)
# ('wheleph0', 0, 4) ('Soloman0', 3, 3)
# ('wheleph0', 1, 'original') ('Aussiroth0', 1, 0)
# ('wheleph0', 1, 0) ('icedtrees0', 4, 0)
# ('wheleph0', 1, 1) ('Koumes210', 0, 4)
# ('wheleph0', 1, 2) ('wheleph0', 1, 4)
# ('wheleph0', 1, 3) ('SierraBravo0', 2, 'original')
# ('wheleph0', 1, 4) ('wheleph0', 1, 2)
# ('wheleph0', 2, 'original') ('Wanseira0', 2, 'original')
# ('wheleph0', 2, 0) ('wheleph0', 2, 2)
# ('wheleph0', 2, 1) ('bigOnion0', 6, 4)
# ('wheleph0', 2, 2) ('shastri0', 4, 2)
# ('wheleph0', 2, 3) ('damo.yu0', 7, 3)
# ('wheleph0', 2, 4) ('bigOnion0', 4, 4)
# ('wheleph0', 3, 'original') ('wheleph0', 3, 4)
# ('wheleph0', 3, 0) ('P.S.0', 2, 1)
# ('wheleph0', 3, 1) ('whaatt0', 2, 'original')
# ('wheleph0', 3, 2) ('nobodyisme0', 2, 2)
# ('wheleph0', 3, 3) ('Tonto0', 2, 1)
# ('wheleph0', 3, 4) ('Wanseira0', 0, 'original')
# ('pumaking940', 0, 'original') ('P.S.0', 0, 3)
# ('pumaking940', 0, 0) ('Aussiroth0', 3, 1)
# ('pumaking940', 0, 1) ('ChevalierMalFet0', 0, 4)
# ('pumaking940', 0, 2) ('progiv0', 2, 3)
# ('pumaking940', 0, 3) ('HexTree0', 1, 'original')
# ('pumaking940', 0, 4) ('whaatt0', 0, 1)
# ('pumaking940', 1, 'original') ('SierraBravo0', 2, 'original')
# ('pumaking940', 1, 0) ('peter.gtz0', 3, 'original')
# ('pumaking940', 1, 1) ('Ardem0', 0, 'original')
# ('pumaking940', 1, 2) ('Tonto0', 2, 4)
# ('pumaking940', 1, 3) ('hector.zhao0', 1, 4)
# ('pumaking940', 1, 4) ('damo.yu0', 5, 'original')
# ('pumaking940', 2, 'original') ('icedtrees0', 4, 'original')
# ('pumaking940', 2, 0) ('SierraBravo0', 2, 'original')
# ('pumaking940', 2, 1) ('P.S.0', 3, 1)
# ('pumaking940', 2, 2) ('P.S.0', 3, 1)
# ('pumaking940', 2, 3) ('hector.zhao0', 1, 2)
# ('pumaking940', 2, 4) ('Ardem0', 0, 'original')
# ('fishball0', 0, 'original') ('takluyver0', 3, 2)
# ('fishball0', 0, 0) ('pumaking940', 1, 1)
# ('fishball0', 0, 1) ('whaatt0', 2, 3)
# ('fishball0', 0, 2) ('peter.gtz0', 4, 0)
# ('fishball0', 0, 3) ('icedtrees0', 4, 3)
# ('fishball0', 0, 4) ('Wanseira0', 2, 3)
# ('fishball0', 1, 'original') ('HexTree0', 1, 'original')
# ('fishball0', 1, 0) ('icedtrees0', 4, 'original')
# ('fishball0', 1, 1) ('SierraBravo0', 2, 'original')
# ('fishball0', 1, 2) ('nobodyisme0', 2, 2)
# ('fishball0', 1, 3) ('HexTree0', 0, 2)
# ('fishball0', 1, 4) ('icedtrees0', 4, 0)
# ('fishball0', 2, 'original') ('fishball0', 2, 0)
# ('fishball0', 2, 0) ('fishball0', 2, 'original')
# ('fishball0', 2, 1) ('coraline0', 2, 0)
# ('fishball0', 2, 2) ('schapel0', 3, 1)
# ('fishball0', 2, 3) ('schapel0', 3, 1)
# ('fishball0', 2, 4) ('ME.py0', 0, 1)
# ('fishball0', 3, 'original') ('fishball0', 3, 1)
# ('fishball0', 3, 0) ('GauravRai0', 2, 0)
# ('fishball0', 3, 1) ('SierraBravo0', 2, 'original')
# ('fishball0', 3, 2) ('fishball0', 3, 3)
# ('fishball0', 3, 3) ('peter.gtz0', 3, 3)
# ('fishball0', 3, 4) ('ChrisJ0', 0, 2)
# ('bbest0', 0, 'original') ('mariusd0', 2, 0)
# ('bbest0', 0, 0) ('cocoatomo0', 2, 1)
# ('bbest0', 0, 1) ('bbest0', 0, 'original')
# ('bbest0', 0, 2) ('waitingkuo05270', 2, 2)
# ('bbest0', 0, 3) ('bbest0', 0, 0)
# ('bbest0', 0, 4) ('bbest0', 2, 4)
# ('bbest0', 1, 'original') ('Wesley0', 3, 2)
# ('bbest0', 1, 0) ('cocoatomo0', 1, 'original')
# ('bbest0', 1, 1) ('bbest0', 2, 0)
# ('bbest0', 1, 2) ('chuck0', 3, 'original')
# ('bbest0', 1, 3) ('waitingkuo05270', 1, 'original')
# ('bbest0', 1, 4) ('Wesley0', 3, 'original')
# ('bbest0', 2, 'original') ('argusdusty0', 2, 2)
# ('bbest0', 2, 0) ('bbest0', 3, 2)
# ('bbest0', 2, 1) ('LouisP0', 2, 2)
# ('bbest0', 2, 2) ('nitsas0', 1, 4)
# ('bbest0', 2, 3) ('waitingkuo05270', 3, 3)
# ('bbest0', 2, 4) ('zerodot0', 3, 3)
# ('bbest0', 3, 'original') ('mgiuca0', 0, 1)
# ('bbest0', 3, 0) ('mariusd0', 0, 4)
# ('bbest0', 3, 1) ('argusdusty0', 3, 0)
# ('bbest0', 3, 2) ('waitingkuo05270', 3, 3)
# ('bbest0', 3, 3) ('chuck0', 2, 0)
# ('bbest0', 3, 4) ('pablo.t890', 4, 0)
# ('bbest0', 4, 'original') ('cocoatomo0', 1, 4)
# ('bbest0', 4, 0) ('bbest0', 3, 2)
# ('bbest0', 4, 1) ('nitsas0', 1, 3)
# ('bbest0', 4, 2) ('farin0', 2, 'original')
# ('bbest0', 4, 3) ('waitingkuo05270', 2, 4)
# ('bbest0', 4, 4) ('argusdusty0', 0, 4)
# ('Kabie0', 0, 'original') ('Kabie0', 3, 1)
# ('Kabie0', 0, 0) ('KennethUlrich0', 3, 1)
# ('Kabie0', 0, 1) ('Bugloon0', 0, 3)
# ('Kabie0', 0, 2) ('KennethUlrich0', 3, 1)
# ('Kabie0', 0, 3) ('waitingkuo05270', 1, 1)
# ('Kabie0', 0, 4) ('voidus0', 3, 2)
# ('Kabie0', 1, 'original') ('Kabie0', 1, 1)
# ('Kabie0', 1, 0) ('Hiking0', 0, 2)
# ('Kabie0', 1, 1) ('dkirienko0', 4, 2)
# ('Kabie0', 1, 2) ('Kabie0', 1, 'original')
# ('Kabie0', 1, 3) ('lkj0', 1, 3)
# ('Kabie0', 1, 4) ('Servy0', 1, 3)
# ('Kabie0', 2, 'original') ('farin0', 3, 'original')
# ('Kabie0', 2, 0) ('Peter.Smit0', 0, 4)
# ('Kabie0', 2, 1) ('jgaten0', 2, 4)
# ('Kabie0', 2, 2) ('Fizu0', 3, 0)
# ('Kabie0', 2, 3) ('pablo.t890', 3, 2)
# ('Kabie0', 2, 4) ('kumarsaurabh0', 3, 2)
# ('Kabie0', 3, 'original') ('KennethUlrich0', 1, 'original')
# ('Kabie0', 3, 0) ('KennethUlrich0', 3, 1)
# ('Kabie0', 3, 1) ('Kabie0', 0, 'original')
# ('Kabie0', 3, 2) ('Bugloon0', 3, 2)
# ('Kabie0', 3, 3) ('KennethUlrich0', 3, 1)
# ('Kabie0', 3, 4) ('Kabie0', 3, 0)
# ('Kabie0', 4, 'original') ('Kabie0', 4, 2)
# ('Kabie0', 4, 0) ('Kabie0', 4, 'original')
# ('Kabie0', 4, 1) ('QuentinB0', 3, 1)
# ('Kabie0', 4, 2) ('Kabie0', 4, 'original')
# ('Kabie0', 4, 3) ('QuentinB0', 2, 3)
# ('Kabie0', 4, 4) ('QuentinB0', 3, 1)
# ('rlyeh0', 0, 'original') ('rlyeh0', 0, 1)
# ('rlyeh0', 0, 0) ('GauravRai0', 2, 3)
# ('rlyeh0', 0, 1) ('rlyeh0', 0, 'original')
# ('rlyeh0', 0, 2) ('Sp30000', 1, 'original')
# ('rlyeh0', 0, 3) ('Ardem0', 1, 1)
# ('rlyeh0', 0, 4) ('HexTree0', 2, 2)
# ('rlyeh0', 1, 'original') ('mgiuca0', 0, 'original')
# ('rlyeh0', 1, 0) ('argusdusty0', 3, 1)
# ('rlyeh0', 1, 1) ('gsz0', 1, 4)
# ('rlyeh0', 1, 2) ('bbest0', 0, 'original')
# ('rlyeh0', 1, 3) ('dareonion0', 0, 4)
# ('rlyeh0', 1, 4) ('rlyeh0', 1, 1)
# ('rlyeh0', 2, 'original') ('rlyeh0', 2, 0)
# ('rlyeh0', 2, 0) ('argusdusty0', 1, 'original')
# ('rlyeh0', 2, 1) ('Fizu0', 3, 1)
# ('rlyeh0', 2, 2) ('argusdusty0', 2, 4)
# ('rlyeh0', 2, 3) ('ali.assaf0', 6, 'original')
# ('rlyeh0', 2, 4) ('waitingkuo05270', 2, 4)
# ('netsuso0', 0, 'original') ('peterr0', 1, 'original')
# ('netsuso0', 0, 0) ('shaunren0', 2, 1)
# ('netsuso0', 0, 1) ('ME.py0', 2, 4)
# ('netsuso0', 0, 2) ('netsuso0', 0, 1)
# ('netsuso0', 0, 3) ('ME.py0', 2, 'original')
# ('netsuso0', 0, 4) ('cocoatomo0', 0, 4)
# ('netsuso0', 1, 'original') ('netsuso0', 1, 4)
# ('netsuso0', 1, 0) ('netsuso0', 1, 4)
# ('netsuso0', 1, 1) ('netsuso0', 1, 4)
# ('netsuso0', 1, 2) ('lkj0', 1, 3)
# ('netsuso0', 1, 3) ('Hato0', 1, 2)
# ('netsuso0', 1, 4) ('netsuso0', 1, 0)
# ('netsuso0', 2, 'original') ('lkj0', 0, 3)
# ('netsuso0', 2, 0) ('201000', 3, 1)
# ('netsuso0', 2, 1) ('Nin00', 1, 'original')
# ('netsuso0', 2, 2) ('brad0', 4, 4)
# ('netsuso0', 2, 3) ('Bugloon0', 2, 3)
# ('netsuso0', 2, 4) ('Nin00', 1, 'original')
# ('netsuso0', 3, 'original') ('brad0', 4, 0)
# ('netsuso0', 3, 0) ('201000', 2, 4)
# ('netsuso0', 3, 1) ('ME.py0', 0, 2)
# ('netsuso0', 3, 2) ('Nin00', 1, 4)
# ('netsuso0', 3, 3) ('coraline0', 0, 'original')
# ('netsuso0', 3, 4) ('shaunren0', 1, 2)
# ('EricStansifer0', 0, 'original') ('mgiuca0', 2, 0)
# ('EricStansifer0', 0, 0) ('ali.assaf0', 3, 0)
# ('EricStansifer0', 0, 1) ('jgaten0', 3, 1)
# ('EricStansifer0', 0, 2) ('EricStansifer0', 2, 2)
# ('EricStansifer0', 0, 3) ('farin0', 2, 'original')
# ('EricStansifer0', 0, 4) ('FatAlex0', 0, 4)
# ('EricStansifer0', 1, 'original') ('FatAlex0', 3, 2)
# ('EricStansifer0', 1, 0) ('EricStansifer0', 5, 'original')
# ('EricStansifer0', 1, 1) ('KennethUlrich0', 0, 0)
# ('EricStansifer0', 1, 2) ('EricStansifer0', 3, 3)
# ('EricStansifer0', 1, 3) ('FatAlex0', 1, 2)
# ('EricStansifer0', 1, 4) ('zerodot0', 1, 0)
# ('EricStansifer0', 2, 'original') ('EricStansifer0', 2, 4)
# ('EricStansifer0', 2, 0) ('waitingkuo05270', 0, 3)
# ('EricStansifer0', 2, 1) ('ali.assaf0', 6, 4)
# ('EricStansifer0', 2, 2) ('RudyGuillan0', 1, 4)
# ('EricStansifer0', 2, 3) ('bbest0', 3, 2)
# ('EricStansifer0', 2, 4) ('EricStansifer0', 2, 'original')
# ('EricStansifer0', 3, 'original') ('EricStansifer0', 5, 3)
# ('EricStansifer0', 3, 0) ('cocoatomo0', 2, 1)
# ('EricStansifer0', 3, 1) ('argusdusty0', 2, 'original')
# ('EricStansifer0', 3, 2) ('Wesley0', 3, 1)
# ('EricStansifer0', 3, 3) ('EricStansifer0', 1, 2)
# ('EricStansifer0', 3, 4) ('KennethUlrich0', 1, 2)
# ('EricStansifer0', 4, 'original') ('EricStansifer0', 1, 3)
# ('EricStansifer0', 4, 0) ('pawko0', 0, 0)
# ('EricStansifer0', 4, 1) ('JustinKang0', 0, 2)
# ('EricStansifer0', 4, 2) ('dareonion0', 2, 4)
# ('EricStansifer0', 4, 3) ('EricStansifer0', 2, 'original')
# ('EricStansifer0', 4, 4) ('pawko0', 7, 1)
# ('EricStansifer0', 5, 'original') ('gsz0', 1, 4)
# ('EricStansifer0', 5, 0) ('FatAlex0', 3, 3)
# ('EricStansifer0', 5, 1) ('EricStansifer0', 5, 2)
# ('EricStansifer0', 5, 2) ('KennethUlrich0', 0, 0)
# ('EricStansifer0', 5, 3) ('KennethUlrich0', 3, 1)
# ('EricStansifer0', 5, 4) ('cocoatomo0', 2, 1)
# ('mitsukoh0', 0, 'original') ('mitsukoh0', 0, 4)
# ('mitsukoh0', 0, 0) ('mitsukoh0', 0, 1)
# ('mitsukoh0', 0, 1) ('mitsukoh0', 0, 'original')
# ('mitsukoh0', 0, 2) ('mitsukoh0', 0, 'original')
# ('mitsukoh0', 0, 3) ('mitsukoh0', 0, 'original')
# ('mitsukoh0', 0, 4) ('mitsukoh0', 0, 'original')
# ('mitsukoh0', 1, 'original') ('mitsukoh0', 1, 2)
# ('mitsukoh0', 1, 0) ('waynerad0', 2, 'original')
# ('mitsukoh0', 1, 1) ('mitsukoh0', 1, 2)
# ('mitsukoh0', 1, 2) ('mitsukoh0', 1, 1)
# ('mitsukoh0', 1, 3) ('shaunren0', 3, 0)
# ('mitsukoh0', 1, 4) ('mitsukoh0', 1, 1)
# ('mitsukoh0', 2, 'original') ('mitsukoh0', 2, 0)
# ('mitsukoh0', 2, 0) ('mitsukoh0', 2, 'original')
# ('mitsukoh0', 2, 1) ('mitsukoh0', 2, 2)
# ('mitsukoh0', 2, 2) ('mitsukoh0', 2, 1)
# ('mitsukoh0', 2, 3) ('bigOnion0', 0, 0)
# ('mitsukoh0', 2, 4) ('mitsukoh0', 2, 0)
# ('mitsukoh0', 3, 'original') ('mitsukoh0', 3, 2)
# ('mitsukoh0', 3, 0) ('mitsukoh0', 3, 'original')
# ('mitsukoh0', 3, 1) ('brad0', 2, 1)
# ('mitsukoh0', 3, 2) ('mitsukoh0', 3, 'original')
# ('mitsukoh0', 3, 3) ('dozingcat0', 4, 1)
# ('mitsukoh0', 3, 4) ('diver0', 0, 0)
# ('Wanseira0', 0, 'original') ('wheleph0', 3, 4)
# ('Wanseira0', 0, 0) ('SierraBravo0', 2, 'original')
# ('Wanseira0', 0, 1) ('icedtrees0', 4, 0)
# ('Wanseira0', 0, 2) ('P.S.0', 3, 1)
# ('Wanseira0', 0, 3) ('progiv0', 0, 1)
# ('Wanseira0', 0, 4) ('Tonto0', 3, 1)
# ('Wanseira0', 1, 'original') ('Tonto0', 0, 0)
# ('Wanseira0', 1, 0) ('takluyver0', 1, 3)
# ('Wanseira0', 1, 1) ('bigOnion0', 4, 3)
# ('Wanseira0', 1, 2) ('P.S.0', 3, 1)
# ('Wanseira0', 1, 3) ('icedtrees0', 4, 0)
# ('Wanseira0', 1, 4) ('P.S.0', 3, 1)
# ('Wanseira0', 2, 'original') ('Tonto0', 0, 0)
# ('Wanseira0', 2, 0) ('P.S.0', 3, 1)
# ('Wanseira0', 2, 1) ('SierraBravo0', 2, 'original')
# ('Wanseira0', 2, 2) ('HexTree0', 1, 1)
# ('Wanseira0', 2, 3) ('peter.gtz0', 1, 1)
# ('Wanseira0', 2, 4) ('SierraBravo0', 2, 'original')
# ('kumarsaurabh0', 0, 'original') ('KennethUlrich0', 3, 1)
# ('kumarsaurabh0', 0, 0) ('FatAlex0', 1, 0)
# ('kumarsaurabh0', 0, 1) ('FatAlex0', 2, 1)
# ('kumarsaurabh0', 0, 2) ('xithan0', 0, 'original')
# ('kumarsaurabh0', 0, 3) ('pawko0', 5, 1)
# ('kumarsaurabh0', 0, 4) ('nobodyisme0', 3, 2)
# ('kumarsaurabh0', 1, 'original') ('killerrex0', 5, 4)
# ('kumarsaurabh0', 1, 0) ('d.operator0', 5, 4)
# ('kumarsaurabh0', 1, 1) ('SAPikachu0', 1, 1)
# ('kumarsaurabh0', 1, 2) ('voidus0', 3, 4)
# ('kumarsaurabh0', 1, 3) ('kumarsaurabh0', 2, 'original')
# ('kumarsaurabh0', 1, 4) ('farin0', 3, 1)
# ('kumarsaurabh0', 2, 'original') ('cocoatomo0', 1, 'original')
# ('kumarsaurabh0', 2, 0) ('FatAlex0', 3, 3)
# ('kumarsaurabh0', 2, 1) ('d.operator0', 0, 3)
# ('kumarsaurabh0', 2, 2) ('alexamici0', 1, 1)
# ('kumarsaurabh0', 2, 3) ('KennethUlrich0', 1, 'original')
# ('kumarsaurabh0', 2, 4) ('ali.assaf0', 5, 4)
# ('kumarsaurabh0', 3, 'original') ('waitingkuo05270', 2, 1)
# ('kumarsaurabh0', 3, 0) ('damo.yu0', 0, 'original')
# ('kumarsaurabh0', 3, 1) ('FatAlex0', 3, 2)
# ('kumarsaurabh0', 3, 2) ('VuryLeo0', 1, 2)
# ('kumarsaurabh0', 3, 3) ('d.operator0', 5, 0)
# ('kumarsaurabh0', 3, 4) ('kumarsaurabh0', 1, 4)
# ('alexamici0', 0, 'original') ('waitingkuo05270', 3, 1)
# ('alexamici0', 0, 0) ('jgaten0', 4, 2)
# ('alexamici0', 0, 1) ('chuck0', 0, 2)
# ('alexamici0', 0, 2) ('rlyeh0', 2, 0)
# ('alexamici0', 0, 3) ('gsz0', 4, 1)
# ('alexamici0', 0, 4) ('Fizu0', 3, 3)
# ('alexamici0', 1, 'original') ('damo.yu0', 6, 1)
# ('alexamici0', 1, 0) ('Bugloon0', 0, 1)
# ('alexamici0', 1, 1) ('KennethUlrich0', 3, 1)
# ('alexamici0', 1, 2) ('KennethUlrich0', 3, 1)
# ('alexamici0', 1, 3) ('alexamici0', 2, 4)
# ('alexamici0', 1, 4) ('barryd0', 0, 'original')
# ('alexamici0', 2, 'original') ('d.operator0', 0, 3)
# ('alexamici0', 2, 0) ('bbest0', 0, 0)
# ('alexamici0', 2, 1) ('EricStansifer0', 0, 4)
# ('alexamici0', 2, 2) ('pawko0', 4, 3)
# ('alexamici0', 2, 3) ('argusdusty0', 0, 1)
# ('alexamici0', 2, 4) ('waitingkuo05270', 1, 1)
# ('alexamici0', 3, 'original') ('alexamici0', 3, 2)
# ('alexamici0', 3, 0) ('alexamici0', 3, 4)
# ('alexamici0', 3, 1) ('Fizu0', 1, 3)
# ('alexamici0', 3, 2) ('Fizu0', 1, 2)
# ('alexamici0', 3, 3) ('alexamici0', 3, 1)
# ('alexamici0', 3, 4) ('VuryLeo0', 0, 2)
# ('j4b0', 0, 'original') ('j4b0', 0, 2)
# ('j4b0', 0, 0) ('j4b0', 1, 4)
# ('j4b0', 0, 1) ('pablo.t890', 4, 0)
# ('j4b0', 0, 2) ('j4b0', 1, 'original')
# ('j4b0', 0, 3) ('gsz0', 1, 4)
# ('j4b0', 0, 4) ('mgiuca0', 2, 0)
# ('j4b0', 1, 'original') ('j4b0', 0, 2)
# ('j4b0', 1, 0) ('Peter.Smit0', 0, 'original')
# ('j4b0', 1, 1) ('j4b0', 4, 2)
# ('j4b0', 1, 2) ('rlyeh0', 1, 'original')
# ('j4b0', 1, 3) ('waitingkuo05270', 0, 1)
# ('j4b0', 1, 4) ('gsz0', 1, 4)
# ('j4b0', 2, 'original') ('j4b0', 4, 4)
# ('j4b0', 2, 0) ('KennethUlrich0', 2, 4)
# ('j4b0', 2, 1) ('kumarsaurabh0', 0, 'original')
# ('j4b0', 2, 2) ('gsz0', 1, 4)
# ('j4b0', 2, 3) ('SAPikachu0', 1, 2)
# ('j4b0', 2, 4) ('j4b0', 3, 2)
# ('j4b0', 3, 'original') ('ali.assaf0', 1, 0)
# ('j4b0', 3, 0) ('bbest0', 4, 4)
# ('j4b0', 3, 1) ('chuck0', 2, 4)
# ('j4b0', 3, 2) ('j4b0', 2, 4)
# ('j4b0', 3, 3) ('bbest0', 1, 0)
# ('j4b0', 3, 4) ('gsz0', 1, 4)
# ('j4b0', 4, 'original') ('j4b0', 0, 2)
# ('j4b0', 4, 0) ('waitingkuo05270', 3, 3)
# ('j4b0', 4, 1) ('nobodyisme0', 3, 1)
# ('j4b0', 4, 2) ('waitingkuo05270', 2, 2)
# ('j4b0', 4, 3) ('bbest0', 3, 2)
# ('j4b0', 4, 4) ('chuck0', 3, 1)
# ('shastri0', 0, 'original') ('SierraBravo0', 2, 'original')
# ('shastri0', 0, 0) ('HexTree0', 0, 0)
# ('shastri0', 0, 1) ('SierraBravo0', 2, 'original')
# ('shastri0', 0, 2) ('fishball0', 0, 2)
# ('shastri0', 0, 3) ('bigOnion0', 3, 1)
# ('shastri0', 0, 4) ('SierraBravo0', 2, 'original')
# ('shastri0', 1, 'original') ('hector.zhao0', 1, 2)
# ('shastri0', 1, 0) ('P.S.0', 3, 1)
# ('shastri0', 1, 1) ('nobodyisme0', 2, 0)
# ('shastri0', 1, 2) ('P.S.0', 3, 1)
# ('shastri0', 1, 3) ('Tonto0', 3, 3)
# ('shastri0', 1, 4) ('P.S.0', 3, 1)
# ('shastri0', 2, 'original') ('shastri0', 2, 4)
# ('shastri0', 2, 0) ('shastri0', 2, 2)
# ('shastri0', 2, 1) ('Bugloon0', 2, 'original')
# ('shastri0', 2, 2) ('ronnodas0', 1, 3)
# ('shastri0', 2, 3) ('ronnodas0', 3, 3)
# ('shastri0', 2, 4) ('shastri0', 2, 'original')
# ('shastri0', 3, 'original') ('shastri0', 3, 3)
# ('shastri0', 3, 0) ('peter.gtz0', 2, 0)
# ('shastri0', 3, 1) ('shastri0', 3, 0)
# ('shastri0', 3, 2) ('Tonto0', 2, 1)
# ('shastri0', 3, 3) ('fishball0', 0, 2)
# ('shastri0', 3, 4) ('pablo.t890', 2, 2)
# ('shastri0', 4, 'original') ('HexTree0', 1, 3)
# ('shastri0', 4, 0) ('takluyver0', 1, 3)
# ('shastri0', 4, 1) ('bigOnion0', 6, 4)
# ('shastri0', 4, 2) ('bigOnion0', 4, 4)
# ('shastri0', 4, 3) ('nobodyisme0', 2, 2)
# ('shastri0', 4, 4) ('whaatt0', 2, 3)
# ('brad0', 0, 'original') ('brad0', 0, 1)
# ('brad0', 0, 0) ('shaunren0', 3, 4)
# ('brad0', 0, 1) ('brad0', 0, 3)
# ('brad0', 0, 2) ('brad0', 1, 'original')
# ('brad0', 0, 3) ('brad0', 0, 1)
# ('brad0', 0, 4) ('shaunren0', 0, 3)
# ('brad0', 1, 'original') ('YOBA0', 0, 4)
# ('brad0', 1, 0) ('brad0', 1, 2)
# ('brad0', 1, 1) ('brad0', 1, 'original')
# ('brad0', 1, 2) ('brad0', 1, 'original')
# ('brad0', 1, 3) ('YOBA0', 0, 3)
# ('brad0', 1, 4) ('shaunren0', 3, 'original')
# ('brad0', 2, 'original') ('lkj0', 3, 1)
# ('brad0', 2, 0) ('lkj0', 0, 1)
# ('brad0', 2, 1) ('lkj0', 3, 1)
# ('brad0', 2, 2) ('BlueFish0', 0, 'original')
# ('brad0', 2, 3) ('ChrisJ0', 0, 0)
# ('brad0', 2, 4) ('brad0', 2, 1)
# ('brad0', 3, 'original') ('Sp30000', 1, 'original')
# ('brad0', 3, 0) ('brad0', 3, 4)
# ('brad0', 3, 1) ('Koumes210', 3, 0)
# ('brad0', 3, 2) ('brad0', 3, 4)
# ('brad0', 3, 3) ('Taizo0', 0, 1)
# ('brad0', 3, 4) ('brad0', 3, 0)
# ('brad0', 4, 'original') ('lkj0', 2, 3)
# ('brad0', 4, 0) ('ronnodas0', 4, 'original')
# ('brad0', 4, 1) ('brad0', 4, 0)
# ('brad0', 4, 2) ('ronnodas0', 4, 'original')
# ('brad0', 4, 3) ('shaunren0', 4, 'original')
# ('brad0', 4, 4) ('netsuso0', 2, 2)
# ('xithan0', 0, 'original') ('waitingkuo05270', 3, 3)
# ('xithan0', 0, 0) ('gsz0', 4, 'original')
# ('xithan0', 0, 1) ('ali.assaf0', 9, 3)
# ('xithan0', 0, 2) ('argusdusty0', 3, 1)
# ('xithan0', 0, 3) ('nobodyisme0', 0, 0)
# ('xithan0', 0, 4) ('mgiuca0', 0, 'original')
# ('xithan0', 1, 'original') ('pablo.t890', 4, 0)
# ('xithan0', 1, 0) ('xithan0', 2, 0)
# ('xithan0', 1, 1) ('gsz0', 1, 4)
# ('xithan0', 1, 2) ('d.operator0', 0, 3)
# ('xithan0', 1, 3) ('argusdusty0', 3, 1)
# ('xithan0', 1, 4) ('mgiuca0', 0, 1)
# ('xithan0', 2, 'original') ('mgiuca0', 0, 2)
# ('xithan0', 2, 0) ('xithan0', 1, 0)
# ('xithan0', 2, 1) ('j4b0', 1, 'original')
# ('xithan0', 2, 2) ('argusdusty0', 3, 1)
# ('xithan0', 2, 3) ('alexamici0', 0, 2)
# ('xithan0', 2, 4) ('xithan0', 2, 1)
# ('xithan0', 3, 'original') ('KennethUlrich0', 0, 0)
# ('xithan0', 3, 0) ('xithan0', 3, 4)
# ('xithan0', 3, 1) ('rlyeh0', 1, 'original')
# ('xithan0', 3, 2) ('xithan0', 2, 'original')
# ('xithan0', 3, 3) ('argusdusty0', 0, 0)
# ('xithan0', 3, 4) ('xithan0', 3, 0)
# ('dozingcat0', 0, 'original') ('dozingcat0', 1, 1)
# ('dozingcat0', 0, 0) ('dozingcat0', 1, 'original')
# ('dozingcat0', 0, 1) ('ME.py0', 2, 'original')
# ('dozingcat0', 0, 2) ('dozingcat0', 3, 2)
# ('dozingcat0', 0, 3) ('ChrisJ0', 0, 0)
# ('dozingcat0', 0, 4) ('dozingcat0', 3, 2)
# ('dozingcat0', 1, 'original') ('dozingcat0', 0, 'original')
# ('dozingcat0', 1, 0) ('dozingcat0', 0, 1)
# ('dozingcat0', 1, 1) ('Hiking0', 0, 'original')
# ('dozingcat0', 1, 2) ('Bugloon0', 2, 'original')
# ('dozingcat0', 1, 3) ('ronnodas0', 1, 3)
# ('dozingcat0', 1, 4) ('GauravRai0', 1, 3)
# ('dozingcat0', 2, 'original') ('Peter.Smit0', 3, 'original')
# ('dozingcat0', 2, 0) ('diver0', 0, 4)
# ('dozingcat0', 2, 1) ('ChrisJ0', 0, 2)
# ('dozingcat0', 2, 2) ('diver0', 0, 3)
# ('dozingcat0', 2, 3) ('farin0', 1, 2)
# ('dozingcat0', 2, 4) ('Servy0', 3, 2)
# ('dozingcat0', 3, 'original') ('diver0', 0, 4)
# ('dozingcat0', 3, 0) ('ssssss0', 2, 2)
# ('dozingcat0', 3, 1) ('diver0', 0, 4)
# ('dozingcat0', 3, 2) ('diver0', 0, 4)
# ('dozingcat0', 3, 3) ('peterr0', 1, 0)
# ('dozingcat0', 3, 4) ('dozingcat0', 3, 2)
# ('dozingcat0', 4, 'original') ('lkj0', 3, 1)
# ('dozingcat0', 4, 0) ('lkj0', 2, 3)
# ('dozingcat0', 4, 1) ('lkj0', 0, 4)
# ('dozingcat0', 4, 2) ('ChrisJ0', 0, 0)
# ('dozingcat0', 4, 3) ('lkj0', 2, 3)
# ('dozingcat0', 4, 4) ('Shurick0', 1, 1)
# ('cocoatomo0', 0, 'original') ('cocoatomo0', 0, 4)
# ('cocoatomo0', 0, 0) ('peterr0', 2, 4)
# ('cocoatomo0', 0, 1) ('cocoatomo0', 0, 3)
# ('cocoatomo0', 0, 2) ('killerrex0', 1, 'original')
# ('cocoatomo0', 0, 3) ('cocoatomo0', 0, 1)
# ('cocoatomo0', 0, 4) ('cocoatomo0', 0, 3)
# ('cocoatomo0', 1, 'original') ('kumarsaurabh0', 0, 'original')
# ('cocoatomo0', 1, 0) ('bbest0', 3, 2)
# ('cocoatomo0', 1, 1) ('bigOnion0', 2, 'original')
# ('cocoatomo0', 1, 2) ('SAPikachu0', 1, 2)
# ('cocoatomo0', 1, 3) ('mgiuca0', 0, 'original')
# ('cocoatomo0', 1, 4) ('voidus0', 2, 2)
# ('cocoatomo0', 2, 'original') ('SAPikachu0', 0, 2)
# ('cocoatomo0', 2, 0) ('waitingkuo05270', 0, 1)
# ('cocoatomo0', 2, 1) ('bbest0', 0, 0)
# ('cocoatomo0', 2, 2) ('dareonion0', 0, 4)
# ('cocoatomo0', 2, 3) ('ali.assaf0', 3, 0)
# ('cocoatomo0', 2, 4) ('d.operator0', 0, 3)
# ('cocoatomo0', 3, 'original') ('cocoatomo0', 3, 4)
# ('cocoatomo0', 3, 0) ('lkj0', 1, 2)
# ('cocoatomo0', 3, 1) ('cocoatomo0', 3, 3)
# ('cocoatomo0', 3, 2) ('cocoatomo0', 3, 'original')
# ('cocoatomo0', 3, 3) ('cocoatomo0', 3, 1)
# ('cocoatomo0', 3, 4) ('cocoatomo0', 3, 'original')
# ('dkirienko0', 0, 'original') ('dkirienko0', 0, 0)
# ('dkirienko0', 0, 0) ('dkirienko0', 0, 1)
# ('dkirienko0', 0, 1) ('killerrex0', 1, 0)
# ('dkirienko0', 0, 2) ('killerrex0', 1, 0)
# ('dkirienko0', 0, 3) ('dkirienko0', 4, 0)
# ('dkirienko0', 0, 4) ('diver0', 3, 2)
# ('dkirienko0', 1, 'original') ('GauravRai0', 4, 3)
# ('dkirienko0', 1, 0) ('dkirienko0', 1, 2)
# ('dkirienko0', 1, 1) ('damo.yu0', 1, 'original')
# ('dkirienko0', 1, 2) ('dkirienko0', 1, 0)
# ('dkirienko0', 1, 3) ('IBar0', 2, 0)
# ('dkirienko0', 1, 4) ('dkirienko0', 1, 'original')
# ('dkirienko0', 2, 'original') ('dkirienko0', 2, 4)
# ('dkirienko0', 2, 0) ('ronnodas0', 3, 2)
# ('dkirienko0', 2, 1) ('schuyler0', 0, 3)
# ('dkirienko0', 2, 2) ('dozingcat0', 1, 3)
# ('dkirienko0', 2, 3) ('schapel0', 3, 4)
# ('dkirienko0', 2, 4) ('dkirienko0', 2, 'original')
# ('dkirienko0', 3, 'original') ('schuyler0', 2, 2)
# ('dkirienko0', 3, 0) ('dkirienko0', 3, 3)
# ('dkirienko0', 3, 1) ('dozingcat0', 1, 3)
# ('dkirienko0', 3, 2) ('Bugloon0', 2, 'original')
# ('dkirienko0', 3, 3) ('lkj0', 0, 3)
# ('dkirienko0', 3, 4) ('lkj0', 0, 3)
# ('dkirienko0', 4, 'original') ('ali.assaf0', 4, 3)
# ('dkirienko0', 4, 0) ('dkirienko0', 4, 'original')
# ('dkirienko0', 4, 1) ('gsz0', 2, 0)
# ('dkirienko0', 4, 2) ('dkirienko0', 4, 4)
# ('dkirienko0', 4, 3) ('damo.yu0', 4, 0)
# ('dkirienko0', 4, 4) ('dkirienko0', 4, 2)
# ('ali.assaf0', 0, 'original') ('SAPikachu0', 2, 1)
# ('ali.assaf0', 0, 0) ('mariusd0', 0, 4)
# ('ali.assaf0', 0, 1) ('xithan0', 2, 0)
# ('ali.assaf0', 0, 2) ('argusdusty0', 1, 'original')
# ('ali.assaf0', 0, 3) ('xithan0', 2, 2)
# ('ali.assaf0', 0, 4) ('gsz0', 1, 4)
# ('ali.assaf0', 1, 'original') ('argusdusty0', 0, 1)
# ('ali.assaf0', 1, 0) ('ali.assaf0', 8, 2)
# ('ali.assaf0', 1, 1) ('ali.assaf0', 6, 2)
# ('ali.assaf0', 1, 2) ('lidaobing0', 1, 4)
# ('ali.assaf0', 1, 3) ('waitingkuo05270', 3, 3)
# ('ali.assaf0', 1, 4) ('gsz0', 1, 4)
# ('ali.assaf0', 2, 'original') ('falcon1123580', 2, 4)
# ('ali.assaf0', 2, 0) ('Kabie0', 2, 1)
# ('ali.assaf0', 2, 1) ('alexamici0', 0, 4)
# ('ali.assaf0', 2, 2) ('mariusd0', 0, 4)
# ('ali.assaf0', 2, 3) ('ali.assaf0', 2, 1)
# ('ali.assaf0', 2, 4) ('rlyeh0', 2, 3)
# ('ali.assaf0', 3, 'original') ('KennethUlrich0', 2, 4)
# ('ali.assaf0', 3, 0) ('chuck0', 0, 2)
# ('ali.assaf0', 3, 1) ('rlyeh0', 2, 'original')
# ('ali.assaf0', 3, 2) ('VuryLeo0', 1, 2)
# ('ali.assaf0', 3, 3) ('waitingkuo05270', 3, 3)
# ('ali.assaf0', 3, 4) ('bbest0', 3, 0)
# ('ali.assaf0', 4, 'original') ('ali.assaf0', 4, 3)
# ('ali.assaf0', 4, 0) ('ali.assaf0', 4, 3)
# ('ali.assaf0', 4, 1) ('ali.assaf0', 4, 0)
# ('ali.assaf0', 4, 2) ('shaunren0', 4, 0)
# ('ali.assaf0', 4, 3) ('ali.assaf0', 4, 0)
# ('ali.assaf0', 4, 4) ('ssssss0', 4, 4)
# ('ali.assaf0', 5, 'original') ('pablo.t890', 4, 'original')
# ('ali.assaf0', 5, 0) ('gsz0', 1, 0)
# ('ali.assaf0', 5, 1) ('RudyGuillan0', 1, 0)
# ('ali.assaf0', 5, 2) ('bbest0', 4, 2)
# ('ali.assaf0', 5, 3) ('KennethUlrich0', 0, 1)
# ('ali.assaf0', 5, 4) ('KennethUlrich0', 0, 0)
# ('ali.assaf0', 6, 'original') ('argusdusty0', 2, 'original')
# ('ali.assaf0', 6, 0) ('ali.assaf0', 0, 4)
# ('ali.assaf0', 6, 1) ('waitingkuo05270', 2, 0)
# ('ali.assaf0', 6, 2) ('ali.assaf0', 1, 1)
# ('ali.assaf0', 6, 3) ('waitingkuo05270', 2, 1)
# ('ali.assaf0', 6, 4) ('EricStansifer0', 2, 1)
# ('ali.assaf0', 7, 'original') ('ali.assaf0', 4, 3)
# ('ali.assaf0', 7, 0) ('201000', 3, 'original')
# ('ali.assaf0', 7, 1) ('shaunren0', 0, 3)
# ('ali.assaf0', 7, 2) ('Nin00', 5, 'original')
# ('ali.assaf0', 7, 3) ('201000', 0, 4)
# ('ali.assaf0', 7, 4) ('shaunren0', 1, 2)
# ('ali.assaf0', 8, 'original') ('ali.assaf0', 1, 'original')
# ('ali.assaf0', 8, 0) ('Simozene0', 2, 2)
# ('ali.assaf0', 8, 1) ('lidaobing0', 3, 0)
# ('ali.assaf0', 8, 2) ('ali.assaf0', 1, 0)
# ('ali.assaf0', 8, 3) ('argusdusty0', 1, 'original')
# ('ali.assaf0', 8, 4) ('xithan0', 0, 'original')
# ('ali.assaf0', 9, 'original') ('kumarsaurabh0', 1, 4)
# ('ali.assaf0', 9, 0) ('mgiuca0', 2, 2)
# ('ali.assaf0', 9, 1) ('ali.assaf0', 2, 2)
# ('ali.assaf0', 9, 2) ('ali.assaf0', 6, 'original')
# ('ali.assaf0', 9, 3) ('gsz0', 3, 3)
# ('ali.assaf0', 9, 4) ('xithan0', 1, 0)
# ('FatAlex0', 0, 'original') ('pablo.t890', 4, 'original')
# ('FatAlex0', 0, 0) ('EricStansifer0', 3, 3)
# ('FatAlex0', 0, 1) ('alexamici0', 2, 0)
# ('FatAlex0', 0, 2) ('bbest0', 3, 2)
# ('FatAlex0', 0, 3) ('waitingkuo05270', 3, 3)
# ('FatAlex0', 0, 4) ('EricStansifer0', 0, 4)
# ('FatAlex0', 1, 'original') ('FatAlex0', 3, 3)
# ('FatAlex0', 1, 0) ('zerodot0', 1, 0)
# ('FatAlex0', 1, 1) ('schapel0', 1, 1)
# ('FatAlex0', 1, 2) ('d.operator0', 0, 3)
# ('FatAlex0', 1, 3) ('kumarsaurabh0', 1, 2)
# ('FatAlex0', 1, 4) ('cocoatomo0', 1, 'original')
# ('FatAlex0', 2, 'original') ('gsz0', 1, 4)
# ('FatAlex0', 2, 0) ('chuck0', 1, 0)
# ('FatAlex0', 2, 1) ('Wesley0', 3, 2)
# ('FatAlex0', 2, 2) ('pawko0', 6, 0)
# ('FatAlex0', 2, 3) ('Wesley0', 0, 2)
# ('FatAlex0', 2, 4) ('d.operator0', 0, 'original')
# ('FatAlex0', 3, 'original') ('RudyGuillan0', 1, 0)
# ('FatAlex0', 3, 0) ('KennethUlrich0', 3, 1)
# ('FatAlex0', 3, 1) ('bbest0', 4, 2)
# ('FatAlex0', 3, 2) ('KennethUlrich0', 3, 1)
# ('FatAlex0', 3, 3) ('KennethUlrich0', 3, 1)
# ('FatAlex0', 3, 4) ('dareonion0', 1, 0)
# ('Sp30000', 0, 'original') ('HexTree0', 0, 4)
# ('Sp30000', 0, 0) ('GauravRai0', 3, 3)
# ('Sp30000', 0, 1) ('fishball0', 1, 'original')
# ('Sp30000', 0, 2) ('BlueFish0', 3, 4)
# ('Sp30000', 0, 3) ('BlueFish0', 1, 2)
# ('Sp30000', 0, 4) ('Sp30000', 4, 'original')
# ('Sp30000', 1, 'original') ('takluyver0', 3, 4)
# ('Sp30000', 1, 0) ('Wanseira0', 1, 2)
# ('Sp30000', 1, 1) ('dennis.lissov0', 0, 3)
# ('Sp30000', 1, 2) ('shastri0', 3, 0)
# ('Sp30000', 1, 3) ('ChevalierMalFet0', 1, 2)
# ('Sp30000', 1, 4) ('Sp30000', 1, 'original')
# ('Sp30000', 2, 'original') ('icedtrees0', 1, 1)
# ('Sp30000', 2, 0) ('hector.zhao0', 1, 2)
# ('Sp30000', 2, 1) ('BlueFish0', 3, 'original')
# ('Sp30000', 2, 2) ('Koumes210', 1, 'original')
# ('Sp30000', 2, 3) ('Sean2230', 1, 3)
# ('Sp30000', 2, 4) ('Koumes210', 1, 'original')
# ('Sp30000', 3, 'original') ('Sp30000', 3, 4)
# ('Sp30000', 3, 0) ('ssssss0', 3, 4)
# ('Sp30000', 3, 1) ('Ardem0', 0, 2)
# ('Sp30000', 3, 2) ('P.S.0', 0, 0)
# ('Sp30000', 3, 3) ('Sp30000', 3, 'original')
# ('Sp30000', 3, 4) ('Sp30000', 3, 'original')
# ('Sp30000', 4, 'original') ('hector.zhao0', 2, 4)
# ('Sp30000', 4, 0) ('icedtrees0', 1, 1)
# ('Sp30000', 4, 1) ('SierraBravo0', 3, 'original')
# ('Sp30000', 4, 2) ('Soloman0', 4, 3)
# ('Sp30000', 4, 3) ('shastri0', 0, 'original')
# ('Sp30000', 4, 4) ('hector.zhao0', 1, 2)
# ('Sp30000', 5, 'original') ('SierraBravo0', 3, 'original')
# ('Sp30000', 5, 0) ('Wanseira0', 1, 4)
# ('Sp30000', 5, 1) ('wheleph0', 3, 4)
# ('Sp30000', 5, 2) ('P.S.0', 1, 1)
# ('Sp30000', 5, 3) ('whaatt0', 2, 3)
# ('Sp30000', 5, 4) ('icedtrees0', 4, 0)
# ('jgaten0', 0, 'original') ('jgaten0', 2, 1)
# ('jgaten0', 0, 0) ('falcon1123580', 2, 0)
# ('jgaten0', 0, 1) ('EricStansifer0', 4, 0)
# ('jgaten0', 0, 2) ('alexamici0', 0, 'original')
# ('jgaten0', 0, 3) ('jgaten0', 1, 0)
# ('jgaten0', 0, 4) ('nobodyisme0', 1, 0)
# ('jgaten0', 1, 'original') ('SAPikachu0', 1, 2)
# ('jgaten0', 1, 0) ('waitingkuo05270', 3, 3)
# ('jgaten0', 1, 1) ('SAPikachu0', 3, 'original')
# ('jgaten0', 1, 2) ('nobodyisme0', 3, 1)
# ('jgaten0', 1, 3) ('bigOnion0', 5, 0)
# ('jgaten0', 1, 4) ('jgaten0', 4, 3)
# ('jgaten0', 2, 'original') ('argusdusty0', 0, 4)
# ('jgaten0', 2, 0) ('rlyeh0', 2, 0)
# ('jgaten0', 2, 1) ('j4b0', 3, 4)
# ('jgaten0', 2, 2) ('falcon1123580', 2, 4)
# ('jgaten0', 2, 3) ('gsz0', 1, 4)
# ('jgaten0', 2, 4) ('SAPikachu0', 1, 1)
# ('jgaten0', 3, 'original') ('EricStansifer0', 2, 0)
# ('jgaten0', 3, 0) ('lidaobing0', 3, 4)
# ('jgaten0', 3, 1) ('waitingkuo05270', 2, 4)
# ('jgaten0', 3, 2) ('alexamici0', 1, 1)
# ('jgaten0', 3, 3) ('Kabie0', 0, 2)
# ('jgaten0', 3, 4) ('gsz0', 1, 4)
# ('jgaten0', 4, 'original') ('jgaten0', 2, 3)
# ('jgaten0', 4, 0) ('gsz0', 1, 4)
# ('jgaten0', 4, 1) ('argusdusty0', 1, 'original')
# ('jgaten0', 4, 2) ('gsz0', 1, 4)
# ('jgaten0', 4, 3) ('jgaten0', 4, 2)
# ('jgaten0', 4, 4) ('bbest0', 3, 2)
# ('ssssss0', 0, 'original') ('axr1230', 3, 4)
# ('ssssss0', 0, 0) ('axr1230', 3, 4)
# ('ssssss0', 0, 1) ('ssssss0', 0, 2)
# ('ssssss0', 0, 2) ('axr1230', 3, 4)
# ('ssssss0', 0, 3) ('peterr0', 0, 3)
# ('ssssss0', 0, 4) ('axr1230', 3, 4)
# ('ssssss0', 1, 'original') ('ssssss0', 1, 1)
# ('ssssss0', 1, 0) ('Hato0', 1, 1)
# ('ssssss0', 1, 1) ('ssssss0', 1, 2)
# ('ssssss0', 1, 2) ('ssssss0', 1, 1)
# ('ssssss0', 1, 3) ('ssssss0', 0, 0)
# ('ssssss0', 1, 4) ('ssssss0', 1, 1)
# ('ssssss0', 2, 'original') ('ssssss0', 2, 4)
# ('ssssss0', 2, 0) ('axr1230', 1, 4)
# ('ssssss0', 2, 1) ('ronnodas0', 6, 2)
# ('ssssss0', 2, 2) ('axr1230', 2, 2)
# ('ssssss0', 2, 3) ('Nin00', 0, 'original')
# ('ssssss0', 2, 4) ('ssssss0', 0, 'original')
# ('ssssss0', 3, 'original') ('ali.assaf0', 4, 3)
# ('ssssss0', 3, 0) ('dennis.lissov0', 1, 4)
# ('ssssss0', 3, 1) ('axr1230', 3, 4)
# ('ssssss0', 3, 2) ('axr1230', 3, 2)
# ('ssssss0', 3, 3) ('ssssss0', 3, 1)
# ('ssssss0', 3, 4) ('Bugloon0', 2, 4)
# ('ssssss0', 4, 'original') ('peterr0', 1, 3)
# ('ssssss0', 4, 0) ('ali.assaf0', 4, 0)
# ('ssssss0', 4, 1) ('ssssss0', 0, 'original')
# ('ssssss0', 4, 2) ('axr1230', 3, 4)
# ('ssssss0', 4, 3) ('ssssss0', 0, 'original')
# ('ssssss0', 4, 4) ('ali.assaf0', 4, 4)
# ('YOBA0', 0, 'original') ('brad0', 1, 3)
# ('YOBA0', 0, 0) ('YOBA0', 0, 3)
# ('YOBA0', 0, 1) ('brad0', 1, 2)
# ('YOBA0', 0, 2) ('ronnodas0', 2, 'original')
# ('YOBA0', 0, 3) ('YOBA0', 0, 4)
# ('YOBA0', 0, 4) ('YOBA0', 0, 3)
# ('YOBA0', 1, 'original') ('YOBA0', 1, 0)
# ('YOBA0', 1, 0) ('YOBA0', 1, 3)
# ('YOBA0', 1, 1) ('YOBA0', 1, 3)
# ('YOBA0', 1, 2) ('YOBA0', 1, 3)
# ('YOBA0', 1, 3) ('YOBA0', 1, 0)
# ('YOBA0', 1, 4) ('Fizu0', 1, 2)
# ('YOBA0', 2, 'original') ('YOBA0', 0, 0)
# ('YOBA0', 2, 0) ('YOBA0', 0, 2)
# ('YOBA0', 2, 1) ('shaunren0', 3, 0)
# ('YOBA0', 2, 2) ('YOBA0', 2, 4)
# ('YOBA0', 2, 3) ('shaunren0', 0, 3)
# ('YOBA0', 2, 4) ('YOBA0', 2, 2)
# ('mariusd0', 0, 'original') ('bbest0', 3, 2)
# ('mariusd0', 0, 0) ('argusdusty0', 3, 1)
# ('mariusd0', 0, 1) ('bbest0', 3, 2)
# ('mariusd0', 0, 2) ('jgaten0', 3, 1)
# ('mariusd0', 0, 3) ('mth0', 7, 4)
# ('mariusd0', 0, 4) ('gsz0', 1, 4)
# ('mariusd0', 1, 'original') ('SAPikachu0', 2, 'original')
# ('mariusd0', 1, 0) ('mth0', 6, 2)
# ('mariusd0', 1, 1) ('argusdusty0', 1, 'original')
# ('mariusd0', 1, 2) ('argusdusty0', 1, 'original')
# ('mariusd0', 1, 3) ('waitingkuo05270', 2, 4)
# ('mariusd0', 1, 4) ('xithan0', 2, 1)
# ('mariusd0', 2, 'original') ('argusdusty0', 3, 1)
# ('mariusd0', 2, 0) ('bbest0', 0, 'original')
# ('mariusd0', 2, 1) ('waitingkuo05270', 0, 1)
# ('mariusd0', 2, 2) ('Wesley0', 1, 3)
# ('mariusd0', 2, 3) ('j4b0', 3, 3)
# ('mariusd0', 2, 4) ('mgiuca0', 0, 'original')
# ('Shurick0', 0, 'original') ('schapel0', 4, 4)
# ('Shurick0', 0, 0) ('Shurick0', 0, 2)
# ('Shurick0', 0, 1) ('Shurick0', 1, 2)
# ('Shurick0', 0, 2) ('GauravRai0', 2, 'original')
# ('Shurick0', 0, 3) ('schuyler0', 2, 4)
# ('Shurick0', 0, 4) ('Shurick0', 1, 2)
# ('Shurick0', 1, 'original') ('nrpeterson0', 0, 'original')
# ('Shurick0', 1, 0) ('nrpeterson0', 2, 'original')
# ('Shurick0', 1, 1) ('GauravRai0', 2, 3)
# ('Shurick0', 1, 2) ('HexTree0', 1, 0)
# ('Shurick0', 1, 3) ('SierraBravo0', 0, 4)
# ('Shurick0', 1, 4) ('nrpeterson0', 0, 'original')
# ('Shurick0', 2, 'original') ('GauravRai0', 2, 3)
# ('Shurick0', 2, 0) ('schuyler0', 1, 3)
# ('Shurick0', 2, 1) ('oonishi0', 1, 1)
# ('Shurick0', 2, 2) ('Shurick0', 2, 'original')
# ('Shurick0', 2, 3) ('Taizo0', 2, 3)
# ('Shurick0', 2, 4) ('oonishi0', 1, 2)
# ('ChrisJ0', 0, 'original') ('damo.yu0', 1, 'original')
# ('ChrisJ0', 0, 0) ('Sp30000', 1, 'original')
# ('ChrisJ0', 0, 1) ('ChrisJ0', 0, 3)
# ('ChrisJ0', 0, 2) ('Koumes210', 2, 4)
# ('ChrisJ0', 0, 3) ('ChrisJ0', 0, 1)
# ('ChrisJ0', 0, 4) ('takluyver0', 4, 3)
# ('ChrisJ0', 1, 'original') ('Sibi0', 0, 1)
# ('ChrisJ0', 1, 0) ('GauravRai0', 2, 2)
# ('ChrisJ0', 1, 1) ('GauravRai0', 0, 1)
# ('ChrisJ0', 1, 2) ('Sibi0', 0, 1)
# ('ChrisJ0', 1, 3) ('ChrisJ0', 1, 2)
# ('ChrisJ0', 1, 4) ('ChrisJ0', 1, 'original')
# ('ChrisJ0', 2, 'original') ('peterr0', 1, 3)
# ('ChrisJ0', 2, 0) ('ChrisJ0', 2, 4)
# ('ChrisJ0', 2, 1) ('ChrisJ0', 2, 4)
# ('ChrisJ0', 2, 2) ('ChrisJ0', 2, 4)
# ('ChrisJ0', 2, 3) ('ChrisJ0', 2, 1)
# ('ChrisJ0', 2, 4) ('ChrisJ0', 2, 1)
# ('GauravRai0', 0, 'original') ('Sibi0', 1, 'original')
# ('GauravRai0', 0, 0) ('schuyler0', 1, 3)
# ('GauravRai0', 0, 1) ('ana.valeije0', 0, 0)
# ('GauravRai0', 0, 2) ('GauravRai0', 3, 3)
# ('GauravRai0', 0, 3) ('GauravRai0', 4, 3)
# ('GauravRai0', 0, 4) ('GauravRai0', 2, 3)
# ('GauravRai0', 1, 'original') ('schuyler0', 1, 2)
# ('GauravRai0', 1, 0) ('GauravRai0', 0, 1)
# ('GauravRai0', 1, 1) ('Ardem0', 2, 'original')
# ('GauravRai0', 1, 2) ('ana.valeije0', 3, 1)
# ('GauravRai0', 1, 3) ('Ardem0', 1, 2)
# ('GauravRai0', 1, 4) ('dkirienko0', 1, 'original')
# ('GauravRai0', 2, 'original') ('Shurick0', 0, 2)
# ('GauravRai0', 2, 0) ('Koumes210', 4, 0)
# ('GauravRai0', 2, 1) ('GauravRai0', 4, 3)
# ('GauravRai0', 2, 2) ('Sibi0', 2, 'original')
# ('GauravRai0', 2, 3) ('nrpeterson0', 0, 'original')
# ('GauravRai0', 2, 4) ('schuyler0', 1, 2)
# ('GauravRai0', 3, 'original') ('schuyler0', 1, 4)
# ('GauravRai0', 3, 0) ('schuyler0', 1, 4)
# ('GauravRai0', 3, 1) ('GauravRai0', 4, 3)
# ('GauravRai0', 3, 2) ('schuyler0', 1, 4)
# ('GauravRai0', 3, 3) ('pumaking940', 0, 4)
# ('GauravRai0', 3, 4) ('schuyler0', 1, 4)
# ('GauravRai0', 4, 'original') ('GauravRai0', 4, 3)
# ('GauravRai0', 4, 0) ('GauravRai0', 0, 1)
# ('GauravRai0', 4, 1) ('GauravRai0', 4, 3)
# ('GauravRai0', 4, 2) ('dkirienko0', 1, 'original')
# ('GauravRai0', 4, 3) ('dkirienko0', 1, 'original')
# ('GauravRai0', 4, 4) ('GauravRai0', 4, 3)
# ('elffikk0', 0, 'original') ('oonishi0', 3, 4)
# ('elffikk0', 0, 0) ('Sp30000', 4, 'original')
# ('elffikk0', 0, 1) ('elffikk0', 2, 2)
# ('elffikk0', 0, 2) ('elffikk0', 0, 'original')
# ('elffikk0', 0, 3) ('HexTree0', 4, 2)
# ('elffikk0', 0, 4) ('elffikk0', 0, 2)
# ('elffikk0', 1, 'original') ('elffikk0', 1, 4)
# ('elffikk0', 1, 0) ('Hato0', 3, 1)
# ('elffikk0', 1, 1) ('elffikk0', 1, 'original')
# ('elffikk0', 1, 2) ('elffikk0', 1, 4)
# ('elffikk0', 1, 3) ('nrpeterson0', 0, 3)
# ('elffikk0', 1, 4) ('damo.yu0', 7, 'original')
# ('elffikk0', 2, 'original') ('icedtrees0', 3, 3)
# ('elffikk0', 2, 0) ('elffikk0', 0, 2)
# ('elffikk0', 2, 1) ('elffikk0', 0, 'original')
# ('elffikk0', 2, 2) ('Koumes210', 2, 2)
# ('elffikk0', 2, 3) ('elffikk0', 0, 'original')
# ('elffikk0', 2, 4) ('Ardem0', 0, 2)
# ('whaatt0', 0, 'original') ('hector.zhao0', 1, 4)
# ('whaatt0', 0, 0) ('shastri0', 1, 2)
# ('whaatt0', 0, 1) ('pumaking940', 0, 4)
# ('whaatt0', 0, 2) ('HexTree0', 1, 3)
# ('whaatt0', 0, 3) ('icedtrees0', 3, 2)
# ('whaatt0', 0, 4) ('whaatt0', 3, 0)
# ('whaatt0', 1, 'original') ('progiv0', 3, 2)
# ('whaatt0', 1, 0) ('hector.zhao0', 1, 2)
# ('whaatt0', 1, 1) ('Tonto0', 3, 'original')
# ('whaatt0', 1, 2) ('Wanseira0', 1, 2)
# ('whaatt0', 1, 3) ('SierraBravo0', 2, 'original')
# ('whaatt0', 1, 4) ('BlueFish0', 3, 'original')
# ('whaatt0', 2, 'original') ('SierraBravo0', 2, 0)
# ('whaatt0', 2, 0) ('hector.zhao0', 1, 2)
# ('whaatt0', 2, 1) ('Aussiroth0', 0, 2)
# ('whaatt0', 2, 2) ('SierraBravo0', 2, 'original')
# ('whaatt0', 2, 3) ('Tonto0', 0, 0)
# ('whaatt0', 2, 4) ('Soloman0', 0, 0)
# ('whaatt0', 3, 'original') ('whaatt0', 1, 2)
# ('whaatt0', 3, 0) ('whaatt0', 1, 'original')
# ('whaatt0', 3, 1) ('whaatt0', 0, 1)
# ('whaatt0', 3, 2) ('progiv0', 1, 'original')
# ('whaatt0', 3, 3) ('hector.zhao0', 1, 2)
# ('whaatt0', 3, 4) ('SierraBravo0', 2, 3)
# ('voidus0', 0, 'original') ('voidus0', 1, 3)
# ('voidus0', 0, 0) ('SierraBravo0', 2, 'original')
# ('voidus0', 0, 1) ('pumaking940', 0, 4)
# ('voidus0', 0, 2) ('Koumes210', 1, 'original')
# ('voidus0', 0, 3) ('Koumes210', 3, 0)
# ('voidus0', 0, 4) ('Sean2230', 1, 'original')
# ('voidus0', 1, 'original') ('voidus0', 1, 3)
# ('voidus0', 1, 0) ('voidus0', 1, 2)
# ('voidus0', 1, 1) ('voidus0', 0, 0)
# ('voidus0', 1, 2) ('Aussiroth0', 3, 1)
# ('voidus0', 1, 3) ('voidus0', 0, 'original')
# ('voidus0', 1, 4) ('Koumes210', 4, 0)
# ('voidus0', 2, 'original') ('mgiuca0', 2, 'original')
# ('voidus0', 2, 0) ('gsz0', 1, 4)
# ('voidus0', 2, 1) ('Simozene0', 0, 1)
# ('voidus0', 2, 2) ('argusdusty0', 2, 2)
# ('voidus0', 2, 3) ('SAPikachu0', 1, 1)
# ('voidus0', 2, 4) ('rlyeh0', 2, 0)
# ('voidus0', 3, 'original') ('d.operator0', 0, 3)
# ('voidus0', 3, 0) ('d.operator0', 0, 3)
# ('voidus0', 3, 1) ('Phayr0', 3, 3)
# ('voidus0', 3, 2) ('alexamici0', 1, 'original')
# ('voidus0', 3, 3) ('alexamici0', 1, 2)
# ('voidus0', 3, 4) ('kumarsaurabh0', 1, 2)
# ('BlueFish0', 0, 'original') ('brad0', 2, 2)
# ('BlueFish0', 0, 0) ('BlueFish0', 0, 'original')
# ('BlueFish0', 0, 1) ('BlueFish0', 0, 3)
# ('BlueFish0', 0, 2) ('GauravRai0', 4, 'original')
# ('BlueFish0', 0, 3) ('BlueFish0', 2, 'original')
# ('BlueFish0', 0, 4) ('ssssss0', 3, 2)
# ('BlueFish0', 1, 'original') ('Ardem0', 2, 0)
# ('BlueFish0', 1, 0) ('BlueFish0', 1, 4)
# ('BlueFish0', 1, 1) ('Shurick0', 2, 1)
# ('BlueFish0', 1, 2) ('icedtrees0', 3, 2)
# ('BlueFish0', 1, 3) ('RudyGuillan0', 3, 'original')
# ('BlueFish0', 1, 4) ('hector.zhao0', 1, 4)
# ('BlueFish0', 2, 'original') ('BlueFish0', 2, 0)
# ('BlueFish0', 2, 0) ('BlueFish0', 2, 'original')
# ('BlueFish0', 2, 1) ('BlueFish0', 2, 'original')
# ('BlueFish0', 2, 2) ('BlueFish0', 2, 'original')
# ('BlueFish0', 2, 3) ('Koumes210', 2, 1)
# ('BlueFish0', 2, 4) ('schuyler0', 1, 3)
# ('BlueFish0', 3, 'original') ('icedtrees0', 4, 'original')
# ('BlueFish0', 3, 0) ('progiv0', 0, 'original')
# ('BlueFish0', 3, 1) ('Koumes210', 0, 4)
# ('BlueFish0', 3, 2) ('elffikk0', 2, 0)
# ('BlueFish0', 3, 3) ('HexTree0', 1, 3)
# ('BlueFish0', 3, 4) ('Aussiroth0', 1, 1)
# ('peterr0', 0, 'original') ('axr1230', 3, 4)
# ('peterr0', 0, 0) ('axr1230', 3, 4)
# ('peterr0', 0, 1) ('peterr0', 0, 0)
# ('peterr0', 0, 2) ('peterr0', 0, 'original')
# ('peterr0', 0, 3) ('peterr0', 0, 'original')
# ('peterr0', 0, 4) ('axr1230', 3, 4)
# ('peterr0', 1, 'original') ('peterr0', 1, 3)
# ('peterr0', 1, 0) ('peterr0', 1, 3)
# ('peterr0', 1, 1) ('Servy0', 1, 1)
# ('peterr0', 1, 2) ('peterr0', 1, 3)
# ('peterr0', 1, 3) ('axr1230', 3, 4)
# ('peterr0', 1, 4) ('peterr0', 1, 3)
# ('peterr0', 2, 'original') ('peterr0', 2, 3)
# ('peterr0', 2, 0) ('peterr0', 2, 4)
# ('peterr0', 2, 1) ('peterr0', 2, 4)
# ('peterr0', 2, 2) ('mitsukoh0', 1, 0)
# ('peterr0', 2, 3) ('peterr0', 2, 4)
# ('peterr0', 2, 4) ('peterr0', 2, 3)
# ('peterr0', 3, 'original') ('peterr0', 3, 4)
# ('peterr0', 3, 0) ('peterr0', 3, 'original')
# ('peterr0', 3, 1) ('GauravRai0', 4, 3)
# ('peterr0', 3, 2) ('GauravRai0', 4, 4)
# ('peterr0', 3, 3) ('peterr0', 3, 'original')
# ('peterr0', 3, 4) ('peterr0', 3, 'original')
# ('ronnodas0', 0, 'original') ('shaunren0', 0, 'original')
# ('ronnodas0', 0, 0) ('schuyler0', 2, 0)
# ('ronnodas0', 0, 1) ('lkj0', 3, 1)
# ('ronnodas0', 0, 2) ('ronnodas0', 0, 1)
# ('ronnodas0', 0, 3) ('brad0', 2, 1)
# ('ronnodas0', 0, 4) ('ronnodas0', 0, 1)
# ('ronnodas0', 1, 'original') ('ronnodas0', 1, 1)
# ('ronnodas0', 1, 0) ('Taizo0', 1, 0)
# ('ronnodas0', 1, 1) ('hirano.y.aa0', 2, 3)
# ('ronnodas0', 1, 2) ('Taizo0', 2, 3)
# ('ronnodas0', 1, 3) ('schapel0', 2, 'original')
# ('ronnodas0', 1, 4) ('Taizo0', 2, 3)
# ('ronnodas0', 2, 'original') ('YOBA0', 0, 2)
# ('ronnodas0', 2, 0) ('schuyler0', 3, 3)
# ('ronnodas0', 2, 1) ('ronnodas0', 2, 3)
# ('ronnodas0', 2, 2) ('ronnodas0', 2, 3)
# ('ronnodas0', 2, 3) ('schuyler0', 3, 3)
# ('ronnodas0', 2, 4) ('schuyler0', 3, 3)
# ('ronnodas0', 3, 'original') ('schuyler0', 2, 'original')
# ('ronnodas0', 3, 0) ('Bugloon0', 2, 'original')
# ('ronnodas0', 3, 1) ('lkj0', 0, 3)
# ('ronnodas0', 3, 2) ('ronnodas0', 4, 'original')
# ('ronnodas0', 3, 3) ('Nin00', 1, 4)
# ('ronnodas0', 3, 4) ('dkirienko0', 3, 'original')
# ('ronnodas0', 4, 'original') ('ronnodas0', 3, 2)
# ('ronnodas0', 4, 0) ('axr1230', 1, 3)
# ('ronnodas0', 4, 1) ('ronnodas0', 2, 2)
# ('ronnodas0', 4, 2) ('ronnodas0', 4, 4)
# ('ronnodas0', 4, 3) ('ronnodas0', 4, 4)
# ('ronnodas0', 4, 4) ('ronnodas0', 4, 2)
# ...
# ('Fizu0', 2, 2) ('waitingkuo05270', 3, 3)
# ('Fizu0', 2, 3) ('ali.assaf0', 9, 0)
# ('Fizu0', 2, 4) ('Fizu0', 2, 1)
# ('Fizu0', 3, 'original') ('Fizu0', 3, 1)
# ('Fizu0', 3, 0) ('Kabie0', 2, 2)
# ('Fizu0', 3, 1) ('j4b0', 1, 'original')
# ('Fizu0', 3, 2) ('takluyver0', 0, 2)
# ('Fizu0', 3, 3) ('gsz0', 1, 4)
# ('Fizu0', 3, 4) ('FatAlex0', 3, 2)
# ('diver0', 0, 'original') ('diver0', 0, 3)
# ('diver0', 0, 0) ('Sibi0', 0, 1)
# ('diver0', 0, 1) ('ronnodas0', 5, 4)
# ('diver0', 0, 2) ('ChrisJ0', 1, 3)
# ('diver0', 0, 3) ('Sibi0', 0, 1)
# ('diver0', 0, 4) ('RalfKistner0', 0, 2)
# ('diver0', 1, 'original') ('Ardem0', 2, 0)
# ('diver0', 1, 0) ('Shurick0', 0, 2)
# ('diver0', 1, 1) ('farin0', 1, 4)
# ('diver0', 1, 2) ('Sibi0', 1, 1)
# ('diver0', 1, 3) ('damo.yu0', 2, 3)
# ('diver0', 1, 4) ('GauravRai0', 0, 1)
# ('diver0', 2, 'original') ('Koumes210', 4, 0)
# ('diver0', 2, 0) ('GauravRai0', 3, 4)
# ('diver0', 2, 1) ('Shurick0', 1, 1)
# ('diver0', 2, 2) ('GauravRai0', 0, 1)
# ('diver0', 2, 3) ('GauravRai0', 0, 1)
# ('diver0', 2, 4) ('RudyGuillan0', 3, 2)
# ('diver0', 3, 'original') ('diver0', 3, 4)
# ('diver0', 3, 0) ('mitsukoh0', 0, 2)
# ('diver0', 3, 1) ('diver0', 3, 4)
# ('diver0', 3, 2) ('diver0', 3, 'original')
# ('diver0', 3, 3) ('diver0', 3, 4)
# ('diver0', 3, 4) ('diver0', 3, 'original')
# ('LouisP0', 0, 'original') ('LouisP0', 2, 0)
# ('LouisP0', 0, 0) ('nitsas0', 2, 2)
# ('LouisP0', 0, 1) ('LouisP0', 3, 3)
# ('LouisP0', 0, 2) ('lidaobing0', 1, 3)
# ('LouisP0', 0, 3) ('LouisP0', 3, 3)
# ('LouisP0', 0, 4) ('LouisP0', 3, 3)
# ('LouisP0', 1, 'original') ('LouisP0', 3, 3)
# ('LouisP0', 1, 0) ('nitsas0', 2, 'original')
# ('LouisP0', 1, 1) ('LouisP0', 2, 0)
# ('LouisP0', 1, 2) ('LouisP0', 1, 'original')
# ('LouisP0', 1, 3) ('nitsas0', 2, 'original')
# ('LouisP0', 1, 4) ('barryd0', 3, 1)
# ('LouisP0', 2, 'original') ('LouisP0', 2, 1)
# ('LouisP0', 2, 0) ('LouisP0', 0, 'original')
# ('LouisP0', 2, 1) ('LouisP0', 3, 3)
# ('LouisP0', 2, 2) ('nitsas0', 2, 2)
# ('LouisP0', 2, 3) ('LouisP0', 0, 2)
# ('LouisP0', 2, 4) ('LouisP0', 0, 3)
# ('LouisP0', 3, 'original') ('LouisP0', 3, 3)
# ('LouisP0', 3, 0) ('Fizu0', 0, 4)
# ('LouisP0', 3, 1) ('chuck0', 2, 3)
# ('LouisP0', 3, 2) ('nitsas0', 2, 'original')
# ('LouisP0', 3, 3) ('LouisP0', 0, 3)
# ('LouisP0', 3, 4) ('alexamici0', 2, 0)
# ('nitsas0', 0, 'original') ('nitsas0', 2, 3)
# ('nitsas0', 0, 0) ('nitsas0', 2, 2)
# ('nitsas0', 0, 1) ('bbest0', 0, 0)
# ('nitsas0', 0, 2) ('barryd0', 3, 'original')
# ('nitsas0', 0, 3) ('FatAlex0', 0, 4)
# ('nitsas0', 0, 4) ('LouisP0', 0, 3)
# ('nitsas0', 1, 'original') ('nitsas0', 2, 2)
# ('nitsas0', 1, 0) ('j4b0', 3, 4)
# ('nitsas0', 1, 1) ('LouisP0', 0, 3)
# ('nitsas0', 1, 2) ('chuck0', 3, 2)
# ('nitsas0', 1, 3) ('nitsas0', 2, 2)
# ('nitsas0', 1, 4) ('nitsas0', 2, 2)
# ('nitsas0', 2, 'original') ('nitsas0', 2, 2)
# ('nitsas0', 2, 0) ('LouisP0', 2, 1)
# ('nitsas0', 2, 1) ('royf0', 2, 1)
# ('nitsas0', 2, 2) ('nitsas0', 2, 'original')
# ('nitsas0', 2, 3) ('nitsas0', 2, 2)
# ('nitsas0', 2, 4) ('nitsas0', 2, 2)
# ('nitsas0', 3, 'original') ('nitsas0', 3, 4)
# ('nitsas0', 3, 0) ('nitsas0', 3, 'original')
# ('nitsas0', 3, 1) ('chuck0', 2, 3)
# ('nitsas0', 3, 2) ('nitsas0', 3, 4)
# ('nitsas0', 3, 3) ('nitsas0', 3, 4)
# ('nitsas0', 3, 4) ('nitsas0', 3, 'original')
# ('Simozene0', 0, 'original') ('pawko0', 3, 0)
# ('Simozene0', 0, 0) ('Simozene0', 0, 1)
# ('Simozene0', 0, 1) ('voidus0', 2, 1)
# ('Simozene0', 0, 2) ('nobodyisme0', 3, 1)
# ('Simozene0', 0, 3) ('SAPikachu0', 1, 1)
# ('Simozene0', 0, 4) ('SAPikachu0', 3, 2)
# ('Simozene0', 1, 'original') ('Peter.Smit0', 1, 0)
# ('Simozene0', 1, 0) ('JustinKang0', 1, 2)
# ('Simozene0', 1, 1) ('Phayr0', 0, 0)
# ('Simozene0', 1, 2) ('lidaobing0', 3, 2)
# ('Simozene0', 1, 3) ('Peter.Smit0', 1, 'original')
# ('Simozene0', 1, 4) ('nobodyisme0', 3, 1)
# ('Simozene0', 2, 'original') ('pawko0', 5, 4)
# ('Simozene0', 2, 0) ('j4b0', 4, 4)
# ('Simozene0', 2, 1) ('SAPikachu0', 1, 'original')
# ('Simozene0', 2, 2) ('rlyeh0', 1, 1)
# ('Simozene0', 2, 3) ('waynerad0', 0, 4)
# ('Simozene0', 2, 4) ('Simozene0', 2, 1)
# ('Simozene0', 3, 'original') ('SAPikachu0', 3, 2)
# ('Simozene0', 3, 0) ('nitsas0', 3, 'original')
# ('Simozene0', 3, 1) ('QuentinB0', 1, 0)
# ('Simozene0', 3, 2) ('bbest0', 2, 0)
# ('Simozene0', 3, 3) ('killerrex0', 2, 0)
# ('Simozene0', 3, 4) ('SAPikachu0', 3, 2)
# ('Tonto0', 0, 'original') ('Wanseira0', 1, 3)
# ('Tonto0', 0, 0) ('SierraBravo0', 2, 'original')
# ('Tonto0', 0, 1) ('SierraBravo0', 2, 'original')
# ('Tonto0', 0, 2) ('peter.gtz0', 4, 0)
# ('Tonto0', 0, 3) ('P.S.0', 3, 1)
# ('Tonto0', 0, 4) ('SierraBravo0', 3, 'original')
# ('Tonto0', 1, 'original') ('hector.zhao0', 1, 4)
# ('Tonto0', 1, 0) ('Aussiroth0', 3, 1)
# ('Tonto0', 1, 1) ('Tonto0', 1, 4)
# ('Tonto0', 1, 2) ('progiv0', 1, 1)
# ('Tonto0', 1, 3) ('Tonto0', 1, 4)
# ('Tonto0', 1, 4) ('Tonto0', 1, 'original')
# ('Tonto0', 2, 'original') ('icedtrees0', 4, 0)
# ('Tonto0', 2, 0) ('hector.zhao0', 1, 2)
# ('Tonto0', 2, 1) ('wheleph0', 3, 3)
# ('Tonto0', 2, 2) ('icedtrees0', 4, 0)
# ('Tonto0', 2, 3) ('hector.zhao0', 1, 2)
# ('Tonto0', 2, 4) ('pumaking940', 1, 2)
# ('Tonto0', 3, 'original') ('peter.gtz0', 1, 1)
# ('Tonto0', 3, 0) ('Koumes210', 1, 1)
# ('Tonto0', 3, 1) ('Tonto0', 3, 'original')
# ('Tonto0', 3, 2) ('SierraBravo0', 2, 'original')
# ('Tonto0', 3, 3) ('shastri0', 1, 3)
# ('Tonto0', 3, 4) ('icedtrees0', 4, 0)
# ('zerodot0', 0, 'original') ('zerodot0', 0, 0)
# ('zerodot0', 0, 0) ('zerodot0', 0, 'original')
# ('zerodot0', 0, 1) ('zerodot0', 0, 0)
# ('zerodot0', 0, 2) ('zerodot0', 0, 'original')
# ('zerodot0', 0, 3) ('zerodot0', 0, 0)
# ('zerodot0', 0, 4) ('zerodot0', 0, 0)
# ('zerodot0', 1, 'original') ('voidus0', 3, 4)
# ('zerodot0', 1, 0) ('Bugloon0', 0, 1)
# ('zerodot0', 1, 1) ('Fizu0', 1, 2)
# ('zerodot0', 1, 2) ('gsz0', 3, 3)
# ('zerodot0', 1, 3) ('KennethUlrich0', 2, 4)
# ('zerodot0', 1, 4) ('d.operator0', 0, 3)
# ('zerodot0', 2, 'original') ('Bugloon0', 3, 4)
# ('zerodot0', 2, 0) ('Wesley0', 0, 0)
# ('zerodot0', 2, 1) ('bbest0', 3, 2)
# ('zerodot0', 2, 2) ('ali.assaf0', 9, 'original')
# ('zerodot0', 2, 3) ('mth0', 4, 1)
# ('zerodot0', 2, 4) ('mgiuca0', 0, 0)
# ('zerodot0', 3, 'original') ('zerodot0', 3, 2)
# ('zerodot0', 3, 0) ('KennethUlrich0', 1, 2)
# ('zerodot0', 3, 1) ('pawko0', 5, 3)
# ('zerodot0', 3, 2) ('zerodot0', 3, 'original')
# ('zerodot0', 3, 3) ('Wesley0', 1, 3)
# ('zerodot0', 3, 4) ('dareonion0', 1, 2)
# ('Taizo0', 0, 'original') ('Taizo0', 0, 4)
# ('Taizo0', 0, 0) ('ChrisJ0', 0, 2)
# ('Taizo0', 0, 1) ('Hato0', 3, 2)
# ('Taizo0', 0, 2) ('whaatt0', 0, 1)
# ('Taizo0', 0, 3) ('Sibi0', 3, 4)
# ('Taizo0', 0, 4) ('Taizo0', 0, 'original')
# ('Taizo0', 1, 'original') ('Taizo0', 1, 3)
# ('Taizo0', 1, 0) ('Taizo0', 1, 'original')
# ('Taizo0', 1, 1) ('Taizo0', 1, 3)
# ('Taizo0', 1, 2) ('Taizo0', 1, 'original')
# ('Taizo0', 1, 3) ('Taizo0', 1, 'original')
# ('Taizo0', 1, 4) ('ChevalierMalFet0', 1, 3)
# ('Taizo0', 2, 'original') ('Taizo0', 3, 1)
# ('Taizo0', 2, 0) ('Taizo0', 0, 2)
# ('Taizo0', 2, 1) ('Taizo0', 2, 'original')
# ('Taizo0', 2, 2) ('Taizo0', 2, 'original')
# ('Taizo0', 2, 3) ('Taizo0', 2, 'original')
# ('Taizo0', 2, 4) ('ronnodas0', 1, 2)
# ('Taizo0', 3, 'original') ('Taizo0', 3, 2)
# ('Taizo0', 3, 0) ('damo.yu0', 2, 'original')
# ('Taizo0', 3, 1) ('Taizo0', 2, 'original')
# ('Taizo0', 3, 2) ('schapel0', 2, 2)
# ('Taizo0', 3, 3) ('Taizo0', 3, 2)
# ('Taizo0', 3, 4) ('Taizo0', 2, 'original')
# ('Aussiroth0', 0, 'original') ('Tonto0', 3, 'original')
# ('Aussiroth0', 0, 0) ('icedtrees0', 1, 'original')
# ('Aussiroth0', 0, 1) ('bigOnion0', 6, 2)
# ('Aussiroth0', 0, 2) ('SierraBravo0', 2, 'original')
# ('Aussiroth0', 0, 3) ('Soloman0', 2, 3)
# ('Aussiroth0', 0, 4) ('progiv0', 2, 0)
# ('Aussiroth0', 1, 'original') ('elffikk0', 0, 2)
# ('Aussiroth0', 1, 0) ('Wanseira0', 1, 3)
# ('Aussiroth0', 1, 1) ('SierraBravo0', 3, 'original')
# ('Aussiroth0', 1, 2) ('hector.zhao0', 1, 2)
# ('Aussiroth0', 1, 3) ('hector.zhao0', 1, 2)
# ('Aussiroth0', 1, 4) ('Tonto0', 2, 1)
# ('Aussiroth0', 2, 'original') ('Aussiroth0', 0, 0)
# ('Aussiroth0', 2, 0) ('Sp30000', 4, 'original')
# ('Aussiroth0', 2, 1) ('bigOnion0', 6, 4)
# ('Aussiroth0', 2, 2) ('icedtrees0', 0, 1)
# ('Aussiroth0', 2, 3) ('Sp30000', 4, 'original')
# ('Aussiroth0', 2, 4) ('HexTree0', 3, 3)
# ('Aussiroth0', 3, 'original') ('fishball0', 0, 3)
# ('Aussiroth0', 3, 0) ('Aussiroth0', 2, 'original')
# ('Aussiroth0', 3, 1) ('elffikk0', 0, 2)
# ('Aussiroth0', 3, 2) ('Nin00', 3, 3)
# ('Aussiroth0', 3, 3) ('Koumes210', 4, 0)
# ('Aussiroth0', 3, 4) ('bigOnion0', 6, 4)
# ('falcon1123580', 0, 'original') ('falcon1123580', 0, 4)
# ('falcon1123580', 0, 0) ('falcon1123580', 0, 4)
# ('falcon1123580', 0, 1) ('falcon1123580', 0, 3)
# ('falcon1123580', 0, 2) ('falcon1123580', 1, 0)
# ('falcon1123580', 0, 3) ('falcon1123580', 1, 0)
# ('falcon1123580', 0, 4) ('falcon1123580', 0, 0)
# ('falcon1123580', 1, 'original') ('falcon1123580', 1, 2)
# ('falcon1123580', 1, 0) ('falcon1123580', 0, 3)
# ('falcon1123580', 1, 1) ('falcon1123580', 0, 3)
# ('falcon1123580', 1, 2) ('falcon1123580', 0, 0)
# ('falcon1123580', 1, 3) ('falcon1123580', 2, 4)
# ('falcon1123580', 1, 4) ('falcon1123580', 2, 4)
# ('falcon1123580', 2, 'original') ('falcon1123580', 2, 2)
# ('falcon1123580', 2, 0) ('VuryLeo0', 2, 4)
# ('falcon1123580', 2, 1) ('falcon1123580', 2, 4)
# ('falcon1123580', 2, 2) ('Phayr0', 1, 0)
# ('falcon1123580', 2, 3) ('Simozene0', 0, 2)
# ('falcon1123580', 2, 4) ('jgaten0', 2, 2)
# ('schuyler0', 0, 'original') ('schuyler0', 2, 4)
# ('schuyler0', 0, 0) ('peter.gtz0', 2, 0)
# ('schuyler0', 0, 1) ('dkirienko0', 2, 1)
# ('schuyler0', 0, 2) ('netsuso0', 3, 1)
# ('schuyler0', 0, 3) ('dkirienko0', 2, 1)
# ('schuyler0', 0, 4) ('ronnodas0', 3, 4)
# ('schuyler0', 1, 'original') ('GauravRai0', 2, 'original')
# ('schuyler0', 1, 0) ('GauravRai0', 0, 1)
# ('schuyler0', 1, 1) ('GauravRai0', 0, 1)
# ('schuyler0', 1, 2) ('GauravRai0', 2, 4)
# ('schuyler0', 1, 3) ('oonishi0', 1, 0)
# ('schuyler0', 1, 4) ('GauravRai0', 3, 4)
# ('schuyler0', 2, 'original') ('schuyler0', 2, 4)
# ('schuyler0', 2, 0) ('ronnodas0', 0, 0)
# ('schuyler0', 2, 1) ('lkj0', 2, 3)
# ('schuyler0', 2, 2) ('shaunren0', 1, 'original')
# ('schuyler0', 2, 3) ('axr1230', 1, 3)
# ('schuyler0', 2, 4) ('schuyler0', 0, 'original')
# ('schuyler0', 3, 'original') ('ChrisJ0', 2, 1)
# ('schuyler0', 3, 0) ('schuyler0', 3, 2)
# ('schuyler0', 3, 1) ('brad0', 4, 0)
# ('schuyler0', 3, 2) ('ME.py0', 0, 2)
# ('schuyler0', 3, 3) ('ronnodas0', 2, 3)
# ('schuyler0', 3, 4) ('lidaobing0', 0, 0)
# ('peter.gtz0', 0, 'original') ('SierraBravo0', 2, 'original')
# ('peter.gtz0', 0, 0) ('peter.gtz0', 2, 0)
# ('peter.gtz0', 0, 1) ('nobodyisme0', 2, 2)
# ('peter.gtz0', 0, 2) ('takluyver0', 1, 0)
# ('peter.gtz0', 0, 3) ('Koumes210', 3, 'original')
# ('peter.gtz0', 0, 4) ('SierraBravo0', 2, 'original')
# ('peter.gtz0', 1, 'original') ('elffikk0', 0, 'original')
# ('peter.gtz0', 1, 0) ('icedtrees0', 4, 0)
# ('peter.gtz0', 1, 1) ('Tonto0', 3, 'original')
# ('peter.gtz0', 1, 2) ('shastri0', 3, 3)
# ('peter.gtz0', 1, 3) ('P.S.0', 3, 1)
# ('peter.gtz0', 1, 4) ('SierraBravo0', 2, 'original')
# ('peter.gtz0', 2, 'original') ('Soloman0', 1, 0)
# ('peter.gtz0', 2, 0) ('peter.gtz0', 2, 4)
# ('peter.gtz0', 2, 1) ('Soloman0', 4, 'original')
# ('peter.gtz0', 2, 2) ('fishball0', 3, 1)
# ('peter.gtz0', 2, 3) ('P.S.0', 1, 1)
# ('peter.gtz0', 2, 4) ('peter.gtz0', 2, 0)
# ('peter.gtz0', 3, 'original') ('icedtrees0', 4, 0)
# ('peter.gtz0', 3, 0) ('peter.gtz0', 3, 1)
# ('peter.gtz0', 3, 1) ('fishball0', 0, 4)
# ('peter.gtz0', 3, 2) ('P.S.0', 3, 1)
# ('peter.gtz0', 3, 3) ('icedtrees0', 4, 3)
# ('peter.gtz0', 3, 4) ('peter.gtz0', 3, 'original')
# ('peter.gtz0', 4, 'original') ('Tonto0', 3, 1)
# ('peter.gtz0', 4, 0) ('fishball0', 0, 2)
# ('peter.gtz0', 4, 1) ('201000', 3, 1)
# ('peter.gtz0', 4, 2) ('SierraBravo0', 2, 'original')
# ('peter.gtz0', 4, 3) ('nobodyisme0', 2, 3)
# ('peter.gtz0', 4, 4) ('Sp30000', 3, 'original')
# ('Phayr0', 0, 'original') ('Phayr0', 0, 1)
# ('Phayr0', 0, 0) ('Phayr0', 3, 0)
# ('Phayr0', 0, 1) ('Phayr0', 0, 'original')
# ('Phayr0', 0, 2) ('voidus0', 3, 3)
# ('Phayr0', 0, 3) ('Phayr0', 3, 0)
# ('Phayr0', 0, 4) ('Phayr0', 0, 'original')
# ('Phayr0', 1, 'original') ('Phayr0', 1, 4)
# ('Phayr0', 1, 0) ('falcon1123580', 2, 2)
# ('Phayr0', 1, 1) ('Kabie0', 2, 1)
# ('Phayr0', 1, 2) ('Simozene0', 2, 1)
# ('Phayr0', 1, 3) ('Kabie0', 2, 1)
# ('Phayr0', 1, 4) ('Kabie0', 2, 1)
# ('Phayr0', 2, 'original') ('Phayr0', 2, 4)
# ('Phayr0', 2, 0) ('Phayr0', 2, 4)
# ('Phayr0', 2, 1) ('netsuso0', 3, 1)
# ('Phayr0', 2, 2) ('YOBA0', 2, 'original')
# ('Phayr0', 2, 3) ('YOBA0', 2, 0)
# ('Phayr0', 2, 4) ('Phayr0', 2, 0)
# ('Phayr0', 3, 'original') ('Bugloon0', 0, 'original')
# ('Phayr0', 3, 0) ('damo.yu0', 6, 1)
# ('Phayr0', 3, 1) ('Bugloon0', 0, 3)
# ('Phayr0', 3, 2) ('voidus0', 3, 2)
# ('Phayr0', 3, 3) ('voidus0', 3, 1)
# ('Phayr0', 3, 4) ('alexamici0', 1, 'original')
# ('waitingkuo05270', 0, 'original') ('SAPikachu0', 2, 'original')
# ('waitingkuo05270', 0, 0) ('EricStansifer0', 3, 3)
# ('waitingkuo05270', 0, 1) ('gsz0', 1, 4)
# ('waitingkuo05270', 0, 2) ('ali.assaf0', 3, 1)
# ('waitingkuo05270', 0, 3) ('waitingkuo05270', 2, 4)
# ('waitingkuo05270', 0, 4) ('lidaobing0', 1, 3)
# ('waitingkuo05270', 1, 'original') ('waitingkuo05270', 3, 3)
# ('waitingkuo05270', 1, 0) ('bbest0', 1, 2)
# ('waitingkuo05270', 1, 1) ('d.operator0', 0, 'original')
# ('waitingkuo05270', 1, 2) ('waitingkuo05270', 2, 4)
# ('waitingkuo05270', 1, 3) ('EricStansifer0', 0, 4)
# ('waitingkuo05270', 1, 4) ('gsz0', 0, 0)
# ('waitingkuo05270', 2, 'original') ('mgiuca0', 0, 0)
# ('waitingkuo05270', 2, 0) ('waitingkuo05270', 3, 3)
# ('waitingkuo05270', 2, 1) ('waitingkuo05270', 0, 1)
# ('waitingkuo05270', 2, 2) ('mariusd0', 2, 0)
# ('waitingkuo05270', 2, 3) ('EricStansifer0', 5, 0)
# ('waitingkuo05270', 2, 4) ('waitingkuo05270', 0, 3)
# ('waitingkuo05270', 3, 'original') ('gsz0', 4, 4)
# ('waitingkuo05270', 3, 0) ('Simozene0', 0, 2)
# ('waitingkuo05270', 3, 1) ('alexamici0', 0, 'original')
# ('waitingkuo05270', 3, 2) ('RudyGuillan0', 1, 'original')
# ('waitingkuo05270', 3, 3) ('bbest0', 3, 2)
# ('waitingkuo05270', 3, 4) ('pablo.t890', 4, 2)
# ('mth0', 0, 'original') ('jgaten0', 3, 1)
# ('mth0', 0, 0) ('damo.yu0', 6, 2)
# ('mth0', 0, 1) ('KennethUlrich0', 1, 'original')
# ('mth0', 0, 2) ('farin0', 3, 1)
# ('mth0', 0, 3) ('mth0', 2, 3)
# ('mth0', 0, 4) ('d.operator0', 5, 4)
# ('mth0', 1, 'original') ('damo.yu0', 4, 4)
# ('mth0', 1, 0) ('mth0', 3, 2)
# ('mth0', 1, 1) ('Servy0', 2, 2)
# ('mth0', 1, 2) ('mth0', 2, 3)
# ('mth0', 1, 3) ('mth0', 1, 'original')
# ('mth0', 1, 4) ('bigOnion0', 2, 2)
# ('mth0', 2, 'original') ('mth0', 2, 0)
# ('mth0', 2, 0) ('mth0', 2, 3)
# ('mth0', 2, 1) ('SAPikachu0', 2, 0)
# ('mth0', 2, 2) ('argusdusty0', 2, 'original')
# ('mth0', 2, 3) ('mth0', 0, 3)
# ('mth0', 2, 4) ('Bugloon0', 0, 3)
# ('mth0', 3, 'original') ('KennethUlrich0', 2, 'original')
# ('mth0', 3, 0) ('kumarsaurabh0', 1, 4)
# ('mth0', 3, 1) ('Bugloon0', 0, 1)
# ('mth0', 3, 2) ('mth0', 2, 3)
# ('mth0', 3, 3) ('Phayr0', 3, 'original')
# ('mth0', 3, 4) ('mth0', 2, 2)
# ('mth0', 4, 'original') ('mgiuca0', 0, 2)
# ('mth0', 4, 0) ('chuck0', 2, 2)
# ('mth0', 4, 1) ('bbest0', 0, 'original')
# ('mth0', 4, 2) ('kumarsaurabh0', 2, 0)
# ('mth0', 4, 3) ('ali.assaf0', 3, 0)
# ('mth0', 4, 4) ('gsz0', 0, 0)
# ('mth0', 5, 'original') ('mth0', 5, 0)
# ('mth0', 5, 0) ('mth0', 5, 2)
# ('mth0', 5, 1) ('bigOnion0', 7, 'original')
# ('mth0', 5, 2) ('mth0', 5, 0)
# ('mth0', 5, 3) ('mth0', 7, 0)
# ('mth0', 5, 4) ('mth0', 5, 0)
# ('mth0', 6, 'original') ('mth0', 6, 1)
# ('mth0', 6, 0) ('mth0', 2, 'original')
# ('mth0', 6, 1) ('mth0', 6, 2)
# ('mth0', 6, 2) ('farin0', 3, 'original')
# ('mth0', 6, 3) ('mth0', 6, 2)
# ('mth0', 6, 4) ('pablo.t890', 0, 4)
# ('mth0', 7, 'original') ('mth0', 7, 3)
# ('mth0', 7, 0) ('rlyeh0', 1, 0)
# ('mth0', 7, 1) ('KennethUlrich0', 0, 2)
# ('mth0', 7, 2) ('pawko0', 3, 0)
# ('mth0', 7, 3) ('mth0', 3, 0)
# ('mth0', 7, 4) ('mariusd0', 0, 3)
# ('Ardem0', 0, 'original') ('pumaking940', 1, 1)
# ('Ardem0', 0, 0) ('SierraBravo0', 3, 'original')
# ('Ardem0', 0, 1) ('SierraBravo0', 3, 'original')
# ('Ardem0', 0, 2) ('icedtrees0', 4, 0)
# ('Ardem0', 0, 3) ('icedtrees0', 1, 1)
# ('Ardem0', 0, 4) ('P.S.0', 3, 1)
# ('Ardem0', 1, 'original') ('damo.yu0', 2, 3)
# ('Ardem0', 1, 0) ('SierraBravo0', 3, 'original')
# ('Ardem0', 1, 1) ('rlyeh0', 0, 3)
# ('Ardem0', 1, 2) ('GauravRai0', 1, 3)
# ('Ardem0', 1, 3) ('progiv0', 1, 1)
# ('Ardem0', 1, 4) ('GauravRai0', 0, 1)
# ('Ardem0', 2, 'original') ('GauravRai0', 4, 3)
# ('Ardem0', 2, 0) ('damo.yu0', 2, 0)
# ('Ardem0', 2, 1) ('GauravRai0', 2, 3)
# ('Ardem0', 2, 2) ('GauravRai0', 2, 2)
# ('Ardem0', 2, 3) ('GauravRai0', 4, 3)
# ('Ardem0', 2, 4) ('rlyeh0', 0, 4)

# %%
list(map(lambda x: len(x), validation_result[1]['metrics'].values()))
# Out:
# [101, 81, 89]

# %%
import gc
gc.collect()
# Out:
# 71

# %%
result = obfuscated_trainer.compare_cos(ast_encoder, batcher.test_data, np.mean)
